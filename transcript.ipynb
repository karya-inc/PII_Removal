# %%
# import requests
# import json

# API_URL = "https://language-server-main-306601896586.us-central1.run.app/v1/transcription"
# API_KEY = "3cFPgIp1-3n4xRDtuxmCl4d6ojPH1hIyLYT3xJBD1WA"

# # Fix path with raw string or forward slashes
# AUDIO_FILE_PATH = r"output_audio\out-8968336334-1001-20250530-150555-1748597755.42124.wav"

# payload_data = {
#     "user_email": "anirudh.pradhan@karya.in",
#     "project_name": "PII Detection and Removal",
#     "task_type": "Batch",
#     "language_identification": False,
#     "metadata": {
#         "priority": "high"
#     },
#     "description": "It's used to separate PII entities from the ASR transcripts of audio samples.",
#     "locale": "hi-IN",
#     "provider": "AZURE",
#     "models": ["long"]
# }

# headers = {
#     "accept": "application/json",
#     "X-API-Key": API_KEY,
# }

# with open(AUDIO_FILE_PATH, "rb") as audio_file:
#     files = {
#         "files": (AUDIO_FILE_PATH, audio_file, "audio/wav"),
#         "payload_data": (None, json.dumps(payload_data), "application/json"),
#     }

#     response = requests.post(API_URL, headers=headers, files=files)

# print("Status code:", response.status_code)
# try:
#     print("Response JSON:", response.json())
# except Exception:
#     print("Response text:", response.text)
# Out:
# Status code: 200
# Response JSON: {'task_id': '6e52712c87f1477d8dc4312b0f475744', 'dataset_id': '2daff7acc98c41f2bdfd8440ff121413', 'status': 'PENDING', 'skipped_file': []}

# %%
import json

import requests

API_URL = (
    "https://language-server-main-306601896586.us-central1.run.app/v1/transcription"
)
API_KEY = "I568wPaBwNi9wLUgUTqX0WdoMpRMBtcOOxIfCS26ehY"


AUDIO_FILE_PATH = (
    r"output_audio\out-8968336334-1001-20250530-150555-1748597755.42124.wav"
)

payload_data = {
    "user_email": "pallavi.sahu@karya.in",
    "project_name": "Individual",
    "task_type": "Batch",
    "language_identification": False,
    "metadata": {"priority": "high"},
    "description": "It's used to separate PII entities from the ASR transcripts of audio samples.",
    "locale": "hi-IN",
    "provider": "AZURE",
    "models": ["long"],
}

headers = {
    "accept": "application/json",
    "X-API-Key": API_KEY,
}

with open(AUDIO_FILE_PATH, "rb") as audio_file:
    files = {
        "files": ("audio.wav", audio_file, "audio/wav"),
    }

    # Pass payload_data as a **string field** in `data`, not in `files`
    data = {
        "payload_data": json.dumps(payload_data)
    }

    response = requests.post(API_URL, headers=headers, files=files, data=data)

print("Status code:", response.status_code)
try:
    print("Response JSON:", response.json())
except Exception:
    print("Response text:", response.text)
# Out:
# Status code: 200
# Response JSON: {'task_id': 'c4f247b4ff1f40558948da0621f0eb83', 'dataset_id': '2dd538524ee14921a542a07e6492662a', 'status': 'PENDING', 'skipped_file': []}

# %%
task_id = response.json().get("task_id")
url = f"https://language-server-main-306601896586.us-central1.run.app/v1/status/{task_id}"

headers = {
    "accept": "application/json",
    "X-API-Key": API_KEY,
}

response1 = requests.get(url, headers=headers)

print("Status Code:", response1.status_code)
print("Response JSON:", response1.json())
# Out:
# Status Code: 200
# Response JSON: {'status': 'COMPLETED', 'responses': [{'id': '5a428ddedf02424b956155742c238142', 'task_id': '399c601606cc444fb4724406df6c388f', 'response': {'output': {'transcriptions': [{'source': 'https://karyaaisa.blob.core.windows.net/langserver/audio_85eda3ecf02a4dbea73aa8ee5a3bc1ab.wav?st=2025-07-27T06%3A58%3A34Z&se=2025-07-28T06%3A58%3A34Z&sp=r&sv=2023-11-03&sr=b&sig=E0J0ue4lX06BKx/2JfBWPKyMdpgenzUgCGnYDZrQYbo%3D', 'duration': 'PT2M30.6S', 'timestamp': '2025-07-27T06:59:03Z', 'durationInTicks': 1506000000, 'recognizedPhrases': [{'nBest': [{'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर', 'words': [{'word': 'हैलो', 'offset': 'PT2.32S', 'duration': 'PT0.16S', 'confidence': 0.8354302, 'offsetInTicks': 23200000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 2320, 'durationMilliseconds': 160}, {'word': 'हैलो', 'offset': 'PT2.48S', 'duration': 'PT0.16S', 'confidence': 0.551557, 'offsetInTicks': 24800000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 2480, 'durationMilliseconds': 160}, {'word': 'हाँ', 'offset': 'PT4.84S', 'duration': 'PT0.12S', 'confidence': 0.8781765, 'offsetInTicks': 48400000.0, 'durationInTicks': 1200000.0, 'offsetMilliseconds': 4840, 'durationMilliseconds': 120}, {'word': 'जी', 'offset': 'PT4.96S', 'duration': 'PT0.2S', 'confidence': 0.9612266, 'offsetInTicks': 49600000.0, 'durationInTicks': 2000000.0, 'offsetMilliseconds': 4960, 'durationMilliseconds': 200}, {'word': 'सस्तिकल', 'offset': 'PT5.16S', 'duration': 'PT0.52S', 'confidence': 0.116050765, 'offsetInTicks': 51600000.0, 'durationInTicks': 5200000.0, 'offsetMilliseconds': 5160, 'durationMilliseconds': 520}, {'word': 'जी', 'offset': 'PT5.68S', 'duration': 'PT0.2S', 'confidence': 0.7048783, 'offsetInTicks': 56800000.0, 'durationInTicks': 2000000.0, 'offsetMilliseconds': 5680, 'durationMilliseconds': 200}, {'word': 'कल', 'offset': 'PT6.44S', 'duration': 'PT0.2S', 'confidence': 0.10360378, 'offsetInTicks': 64400000.0, 'durationInTicks': 2000000.0, 'offsetMilliseconds': 6440, 'durationMilliseconds': 200}, {'word': 'कर', 'offset': 'PT6.64S', 'duration': 'PT0.16S', 'confidence': 0.35214725, 'offsetInTicks': 66400000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 6640, 'durationMilliseconds': 160}, {'word': 'रहे', 'offset': 'PT6.8S', 'duration': 'PT0.16S', 'confidence': 0.5811583, 'offsetInTicks': 68000000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 6800, 'durationMilliseconds': 160}, {'word': 'थे', 'offset': 'PT6.96S', 'duration': 'PT0.16S', 'confidence': 0.16865757, 'offsetInTicks': 69600000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 6960, 'durationMilliseconds': 160}, {'word': 'हाँ', 'offset': 'PT7.96S', 'duration': 'PT0.16S', 'confidence': 0.4616028, 'offsetInTicks': 79600000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 7960, 'durationMilliseconds': 160}, {'word': 'जी', 'offset': 'PT8.12S', 'duration': 'PT0.12S', 'confidence': 0.72985035, 'offsetInTicks': 81200000.0, 'durationInTicks': 1200000.0, 'offsetMilliseconds': 8120, 'durationMilliseconds': 120}, {'word': 'देव', 'offset': 'PT8.92S', 'duration': 'PT0.16S', 'confidence': 0.15332341, 'offsetInTicks': 89200000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 8920, 'durationMilliseconds': 160}, {'word': 'सिंह', 'offset': 'PT9.12S', 'duration': 'PT0.2S', 'confidence': 0.3751822, 'offsetInTicks': 91200000.0, 'durationInTicks': 2000000.0, 'offsetMilliseconds': 9120, 'durationMilliseconds': 200}, {'word': 'जी', 'offset': 'PT9.32S', 'duration': 'PT0.08S', 'confidence': 0.786756, 'offsetInTicks': 93200000.0, 'durationInTicks': 800000.0, 'offsetMilliseconds': 9320, 'durationMilliseconds': 80}, {'word': 'मैं', 'offset': 'PT9.4S', 'duration': 'PT0.16S', 'confidence': 0.78136235, 'offsetInTicks': 94000000.0, 'durationInTicks': 1600000.0, 'offsetMilliseconds': 9400, 'durationMilliseconds': 160}, {'word': 'कल्टीवेट', 'offset': 'PT9.56S', 'd ...

# %%
response1.json()
# Out:
# {'status': 'COMPLETED',
#  'responses': [{'id': '5a428ddedf02424b956155742c238142',
#    'task_id': '399c601606cc444fb4724406df6c388f',
#    'response': {'output': {'transcriptions': [{'source': 'https://karyaaisa.blob.core.windows.net/langserver/audio_85eda3ecf02a4dbea73aa8ee5a3bc1ab.wav?st=2025-07-27T06%3A58%3A34Z&se=2025-07-28T06%3A58%3A34Z&sp=r&sv=2023-11-03&sr=b&sig=E0J0ue4lX06BKx/2JfBWPKyMdpgenzUgCGnYDZrQYbo%3D',
#        'duration': 'PT2M30.6S',
#        'timestamp': '2025-07-27T06:59:03Z',
#        'durationInTicks': 1506000000,
#        'recognizedPhrases': [{'nBest': [{'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354302,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.551557,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781765,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048783,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.5811583,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.4616028,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751822,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136235,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991724,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.8268918,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614266,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8664881,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'कल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10043929,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.74404544,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7979985,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.3168954,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.1551322,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'को',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.12S',
#              'confidence': 0.1425455,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 120},
#             {'word': 'ना',
#              'offset': 'PT12.56S',
#              'duration': 'PT0.16S',
#              'confidence': 0.117057525,
#              'offsetInTicks': 125600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 12560,
#              'durationMilliseconds': 160},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.54721934,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.35077906,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.50296366,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.7872108,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.62966824,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.13587242,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर।',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर।',
#            'confidence': 0.50449187},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354302,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.551557,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781765,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048783,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.5811583,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.4616028,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751822,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136235,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991724,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.8268918,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614266,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8664881,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'गल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.11122753,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.9320308,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7692381,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.32034338,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.16068487,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'को',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.12S',
#              'confidence': 0.14789782,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 120},
#             {'word': 'ना',
#              'offset': 'PT12.56S',
#              'duration': 'PT0.16S',
#              'confidence': 0.11307252,
#              'offsetInTicks': 125600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 12560,
#              'durationMilliseconds': 160},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.51886654,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.33332315,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.50032884,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.79459065,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.6198647,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.13423508,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'confidence': 0.5083669},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354306,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.55155706,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781767,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048784,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.58115834,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.46160287,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751824,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136265,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991753,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.82689226,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614275,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.86648834,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'गल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.11122753,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.932031,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7692384,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.32034338,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.16068484,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'के',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.08S',
#              'confidence': 0.048774496,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 80},
#             {'word': 'लिए',
#              'offset': 'PT12.48S',
#              'duration': 'PT0.44S',
#              'confidence': 0.1416222,
#              'offsetInTicks': 124800000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 12480,
#              'durationMilliseconds': 440},
#             {'word': 'ना',
#              'offset': 'PT12.92S',
#              'duration': 'PT0.08S',
#              'confidence': 0.3017459,
#              'offsetInTicks': 129200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 12920,
#              'durationMilliseconds': 80},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.5469415,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.33998123,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.49781072,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.7892813,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.62477577,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.12325713,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'confidence': 0.5008271},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354306,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.55155706,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781767,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048784,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.58115834,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.46160287,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751824,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136265,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991753,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.82689226,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614275,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.86648834,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'गल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.11122753,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.932031,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7692384,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.32034338,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.16068484,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'को',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.08S',
#              'confidence': 0.14789785,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 80},
#             {'word': 'ले',
#              'offset': 'PT12.48S',
#              'duration': 'PT0.12S',
#              'confidence': 0.025268108,
#              'offsetInTicks': 124800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12480,
#              'durationMilliseconds': 120},
#             {'word': 'ना',
#              'offset': 'PT12.6S',
#              'duration': 'PT0.12S',
#              'confidence': 0.44332874,
#              'offsetInTicks': 126000000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12600,
#              'durationMilliseconds': 120},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.5204434,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.32141152,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.49334845,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.7887503,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.61688095,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.1289646,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'confidence': 0.50294775},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम बार',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354302,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.551557,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781765,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612267,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.70487833,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.5811583,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
# ...
#              'offset': 'PT2M25.64S',
#              'duration': 'PT0.2S',
#              'confidence': 0.5073979,
#              'offsetInTicks': 1456400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 145640,
#              'durationMilliseconds': 200},
#             {'word': 'धन्यवाद',
#              'offset': 'PT2M25.84S',
#              'duration': 'PT0.68S',
#              'confidence': 0.5447692,
#              'offsetInTicks': 1458400000.0,
#              'durationInTicks': 6800000.0,
#              'offsetMilliseconds': 145840,
#              'durationMilliseconds': 680},
#             {'word': 'सर',
#              'offset': 'PT2M26.56S',
#              'duration': 'PT0.12S',
#              'confidence': 0.47606575,
#              'offsetInTicks': 1465600000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 146560,
#              'durationMilliseconds': 120},
#             {'word': 'ओके',
#              'offset': 'PT2M27.08S',
#              'duration': 'PT0.2S',
#              'confidence': 0.59440196,
#              'offsetInTicks': 1470800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 147080,
#              'durationMilliseconds': 200},
#             {'word': 'थैंक',
#              'offset': 'PT2M27.28S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8798975,
#              'offsetInTicks': 1472800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 147280,
#              'durationMilliseconds': 160},
#             {'word': 'यू',
#              'offset': 'PT2M27.44S',
#              'duration': 'PT0.08S',
#              'confidence': 0.53551394,
#              'offsetInTicks': 1474400000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 147440,
#              'durationMilliseconds': 80},
#             {'word': 'मैडम',
#              'offset': 'PT2M27.64S',
#              'duration': 'PT0.2S',
#              'confidence': 0.31638944,
#              'offsetInTicks': 1476400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 147640,
#              'durationMilliseconds': 200}],
#            'display': 'सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समय देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम',
#            'lexical': 'सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समय देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम',
#            'maskedITN': 'सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समय देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम',
#            'confidence': 0.4734029}],
#          'offset': 'PT2M9S',
#          'channel': 0,
#          'duration': 'PT18.84S',
#          'offsetInTicks': 1290000000.0,
#          'durationInTicks': 188400000.0,
#          'recognitionStatus': 'Success',
#          'offsetMilliseconds': 129000,
#          'durationMilliseconds': 18840},
#         {'nBest': [{'itn': 'ओके सर',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.68S',
#              'confidence': 0.836343,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 6800000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 680}],
#            'display': 'ओके सर।',
#            'lexical': 'ओके सर',
#            'maskedITN': 'ओके सर।',
#            'confidence': 0.8227327},
#           {'itn': 'ओके सर सस्ती का',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.2S',
#              'confidence': 0.836343,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 200},
#             {'word': 'सस्ती',
#              'offset': 'PT2M28.48S',
#              'duration': 'PT0.28S',
#              'confidence': 0.10090179,
#              'offsetInTicks': 1484800000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 148480,
#              'durationMilliseconds': 280},
#             {'word': 'का',
#              'offset': 'PT2M28.76S',
#              'duration': 'PT0.48S',
#              'confidence': 0.101739444,
#              'offsetInTicks': 1487600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 148760,
#              'durationMilliseconds': 480}],
#            'display': 'ओके सर सस्ती का',
#            'lexical': 'ओके सर सस्ती का',
#            'maskedITN': 'ओके सर सस्ती का',
#            'confidence': 0.46202666},
#           {'itn': 'ओके सर सस्ती',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.32S',
#              'confidence': 0.836343,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 320},
#             {'word': 'सस्ती',
#              'offset': 'PT2M28.6S',
#              'duration': 'PT0.56S',
#              'confidence': 0.10090179,
#              'offsetInTicks': 1486000000.0,
#              'durationInTicks': 5600000.0,
#              'offsetMilliseconds': 148600,
#              'durationMilliseconds': 560}],
#            'display': 'ओके सर सस्ती',
#            'lexical': 'ओके सर सस्ती',
#            'maskedITN': 'ओके सर सस्ती',
#            'confidence': 0.58212245},
#           {'itn': 'ओके सर सस्ती कल',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.80912304,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.2S',
#              'confidence': 0.83634305,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 200},
#             {'word': 'सस्ती',
#              'offset': 'PT2M28.48S',
#              'duration': 'PT0.28S',
#              'confidence': 0.10090179,
#              'offsetInTicks': 1484800000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 148480,
#              'durationMilliseconds': 280},
#             {'word': 'कल',
#              'offset': 'PT2M28.76S',
#              'duration': 'PT0.24S',
#              'confidence': 0.0028936125,
#              'offsetInTicks': 1487600000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148760,
#              'durationMilliseconds': 240}],
#            'display': 'ओके सर सस्ती कल',
#            'lexical': 'ओके सर सस्ती कल',
#            'maskedITN': 'ओके सर सस्ती कल',
#            'confidence': 0.43731537},
#           {'itn': 'ओके',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.84S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 8400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 840}],
#            'display': 'ओके',
#            'lexical': 'ओके',
#            'maskedITN': 'ओके',
#            'confidence': 0.8091224}],
#          'offset': 'PT2M28.04S',
#          'channel': 0,
#          'duration': 'PT0.92S',
#          'offsetInTicks': 1480400000.0,
#          'durationInTicks': 9200000.0,
#          'recognitionStatus': 'Success',
#          'offsetMilliseconds': 148040,
#          'durationMilliseconds': 920}],
#        'durationMilliseconds': 150600,
#        'combinedRecognizedPhrases': [{'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है मतलब अपा जीतने भी इंसान है क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी थोड़े फ़ोन पे मैसेज आना है सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े 24 पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम ओके सर',
#          'channel': 0,
#          'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर। हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके, बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में। हाँ जी, बीएन सिंह जी, ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर, पानी लागने अंदर है। दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है। मतलब अपा जीतने भी इंसान है। क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके? सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है। थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है, ठीक है ना? और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी। थोड़े फ़ोन पे मैसेज आना है। सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई। ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी, थोड़ी सी पानी भी बचत हुई। एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर। उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है, कदु करना है, है ना? इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है, मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना? जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी, ओनली जल्दी रबड़ की है ना? सर, कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े 24 पैदावार है। और भी बचूगी हाँ जी ठीक है सर हाँ जी सर, समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके, थैंक यू मैडम। ओके सर।',
#          'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है मतलब अपा जीतने भी इंसान है क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी थोड़े फ़ोन पे मैसेज आना है सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम ओके सर',
#          'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर। हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में। हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है। दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है। मतलब अपा जीतने भी इंसान है। क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है। थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी। थोड़े फ़ोन पे मैसेज आना है। सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई। ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई। एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर। उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े 24 पैदावार है। और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम। ओके सर।'}]}]},
#     'task_id': '399c601606cc444fb4724406df6c388f',
#     'provider': 'AZURE',
#     'dataset_id': '4fcbd4cc048b4d109f20502eb9968017',
#     'output_file': 'https://karyaaisa.blob.core.windows.net/langserver/399c601606cc444fb4724406df6c388f.json'},
#    'created_at': '2025-07-27T06:59:13.327175',
#    'updated_at': None}]}

# %%
import json
import requests
import time

# Constants - keep your URL, API key, headers, and payload separate
API_URL = "https://language-server-main-306601896586.us-central1.run.app/v1/transcription"
API_KEY = "I568wPaBwNi9wLUgUTqX0WdoMpRMBtcOOxIfCS26ehY"
AUDIO_FILE_PATH = r"output_audio\out-8968336334-1001-20250530-150555-1748597755.42124.wav"

HEADERS = {
    "accept": "application/json",
    "X-API-Key": API_KEY,
}

PAYLOAD_DATA = {
    "user_email": "pallavi.sahu@karya.in",
    "project_name": "Individual",
    "task_type": "Batch",
    "language_identification": False,
    "metadata": {"priority": "high"},
    "description": "It's used to separate PII entities from the ASR transcripts of audio samples.",
    "locale": "hi-IN",
    "provider": "AZURE",
    "models": ["long"],
}

# %%
def submit_transcription(api_url, headers, audio_file_path, payload_data):
    with open(audio_file_path, "rb") as audio_file:
        files = {
            "files": ("audio.wav", audio_file, "audio/wav"),
        }
        # Pass payload_data as a string field in 'data' parameter (not files)
        data = {
            "payload_data": json.dumps(payload_data)
        }

        response = requests.post(api_url, headers=headers, files=files, data=data)

    print("Status code:", response.status_code)
    try:
        print("Response JSON:", response.json())
        return response.json()
    except Exception:
        print("Response text:", response.text)
        return None

# %%
def poll_status(task_id, wait_seconds=20, max_retries=10):
    status_url = f"https://language-server-main-306601896586.us-central1.run.app/v1/status/{task_id}"
    for attempt in range(max_retries):
        response = requests.get(status_url, headers=HEADERS)
        print(f"Polling attempt {attempt+1}, Status Code:", response.status_code)
        if response.status_code != 200:
            print("Error getting status:", response.text)
            return None
        data = response.json()
        status = data.get("status")
        print("Current status:", status)
        if status == "COMPLETED":
            return data
        elif status in ["FAILED", "CANCELLED"]:
            print(f"Task ended with status: {status}")
            return None
        time.sleep(wait_seconds)
    print("Max retries reached without completion.")
    return None

# %%
def extract_asr_transcript(data):
    # This assumes the data structure from the response JSON contains an 'responses' list.
    # Each response's 'output' contains 'transcriptions' which include 'recognizedPhrases' → list of phrases with words.
    responses = data.get("responses", [])
    if not responses:
        print("No responses found in data.")
        return None

    transcriptions = responses[0].get("response", {}).get("output", {}).get("transcriptions", [])
    if not transcriptions:
        print("No transcriptions found.")
        return None

    # Extract all word-level chunks with text and timestamps
    words_chunks = []
    for transcription in transcriptions:
        recognizedPhrases = transcription.get("recognizedPhrases", [])
        for phrase in recognizedPhrases:
            # 'nBest' is a list of hypotheses; we use the first one (best)
            nbest = phrase.get("nBest", [])
            if not nbest:
                continue
            best_hypo = nbest[0]
            words = best_hypo.get("words", [])
            for w in words:
                # Each word dict should have 'word', 'offsetMilliseconds', 'durationMilliseconds'
                text = w.get("word")
                start_ms = w.get("offsetMilliseconds")  # int, milliseconds
                dur_ms = w.get("durationMilliseconds")
                if text is None or start_ms is None or dur_ms is None:
                    continue
                start_s = start_ms / 1000.0
                end_s = (start_ms + dur_ms) / 1000.0
                words_chunks.append({
                    "text": text,
                    "timestamp": (start_s, end_s)
                })

    # Aggregate full text by joining word texts with space (adjust if ASR text needs special handling)
    full_text = " ".join(chunk["text"] for chunk in words_chunks)

    transcript = {
        "text": full_text,
        "chunks": words_chunks
    }

    return transcript

# %%
# def main():
#     response = submit_transcription(API_URL, HEADERS, AUDIO_FILE_PATH, PAYLOAD_DATA)
#     if not response:
#         print("Failed to submit transcription.")
#         return

#     task_id = response.get("task_id")  # directly get task_id from returned dictionary
#     if not task_id:
#         print("Failed to retrieve task ID from response.")
#         return

#     print(f"Submitted transcription task. Task ID: {task_id}")
#     print("Polling for completion...")

#     result_data = poll_status(task_id)
#     if not result_data:
#         print("Failed to get transcription result or task did not complete.")
#         return

#     transcript = extract_asr_transcript(result_data)
#     if not transcript:
#         print("Failed to extract transcript.")
#         return

#     # Print/output transcript JSON with word-level timestamps
#     print("\nFinal Transcript JSON:")
#     print(json.dumps(transcript, ensure_ascii=False, indent=2))

# %%
main()
# Out:
# Status code: 200
# Response JSON: {'task_id': 'd8d1cf672b19475f8e3fe81b5cea156d', 'dataset_id': '64cad9025f4d4444a161f57a299d7a9e', 'status': 'PENDING', 'skipped_file': []}
# Submitted transcription task. Task ID: d8d1cf672b19475f8e3fe81b5cea156d
# Polling for completion...
# Polling attempt 1, Status Code: 200
# Current status: PENDING
# Polling attempt 2, Status Code: 200
# Current status: PENDING
# Polling attempt 3, Status Code: 200
# Current status: COMPLETED
#
# Final Transcript JSON:
# {
#   "text": "हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है मतलब अपा जीतने भी इंसान है क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी थोड़े फ़ोन पे मैसेज आना है सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम ओके सर",
#   "chunks": [
#     {
#       "text": "हैलो",
#       "timestamp": [
#         2.32,
#         2.48
#       ]
#     },
#     {
#       "text": "हैलो",
#       "timestamp": [
#         2.48,
#         2.64
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         4.84,
#         4.96
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         4.96,
#         5.16
#       ]
#     },
#     {
#       "text": "सस्तिकल",
#       "timestamp": [
#         5.16,
#         5.68
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         5.68,
#         5.88
#       ]
#     },
#     {
#       "text": "कल",
#       "timestamp": [
#         6.44,
#         6.64
#       ]
#     },
#     {
#       "text": "कर",
#       "timestamp": [
#         6.64,
#         6.8
#       ]
#     },
#     {
#       "text": "रहे",
#       "timestamp": [
#         6.8,
#         6.96
#       ]
#     },
#     {
#       "text": "थे",
#       "timestamp": [
#         6.96,
#         7.12
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         7.96,
#         8.12
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         8.12,
#         8.24
#       ]
#     },
#     {
#       "text": "देव",
#       "timestamp": [
#         8.92,
#         9.08
#       ]
#     },
#     {
#       "text": "सिंह",
#       "timestamp": [
#         9.12,
#         9.32
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         9.32,
#         9.4
#       ]
#     },
#     {
#       "text": "मैं",
#       "timestamp": [
#         9.4,
#         9.56
#       ]
#     },
#     {
#       "text": "कल्टीवेट",
#       "timestamp": [
#         9.56,
#         10.04
#       ]
#     },
#     {
#       "text": "कंपनी",
#       "timestamp": [
#         10.04,
#         10.44
#       ]
#     },
#     {
#       "text": "पटियाले",
#       "timestamp": [
#         10.44,
#         10.88
#       ]
#     },
#     {
#       "text": "तो",
#       "timestamp": [
#         10.88,
#         11.0
#       ]
#     },
#     {
#       "text": "कल",
#       "timestamp": [
#         11.0,
#         11.2
#       ]
#     },
#     {
#       "text": "कर",
#       "timestamp": [
#         11.2,
#         11.36
#       ]
#     },
#     {
#       "text": "रही",
#       "timestamp": [
#         11.36,
#         11.64
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         11.72,
#         11.8
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         12.08,
#         12.4
#       ]
#     },
#     {
#       "text": "को",
#       "timestamp": [
#         12.4,
#         12.52
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         12.56,
#         12.72
#       ]
#     },
#     {
#       "text": "लड़का",
#       "timestamp": [
#         13.68,
#         14.0
#       ]
#     },
#     {
#       "text": "आया",
#       "timestamp": [
#         14.0,
#         14.28
#       ]
#     },
#     {
#       "text": "उन्होंने",
#       "timestamp": [
#         14.36,
#         14.72
#       ]
#     },
#     {
#       "text": "कार्बन",
#       "timestamp": [
#         14.72,
#         15.16
#       ]
#     },
#     {
#       "text": "प्रोग्राम",
#       "timestamp": [
#         15.2,
#         15.6
#       ]
#     },
#     {
#       "text": "पर",
#       "timestamp": [
#         15.6,
#         15.92
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         18.12,
#         18.2
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         18.2,
#         18.36
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         18.36,
#         18.6
#       ]
#     },
#     {
#       "text": "मैं",
#       "timestamp": [
#         18.6,
#         18.84
#       ]
#     },
#     {
#       "text": "मैडम",
#       "timestamp": [
#         19.84,
#         20.08
#       ]
#     },
#     {
#       "text": "वो",
#       "timestamp": [
#         20.12,
#         20.6
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         20.6,
#         20.72
#       ]
#     },
#     {
#       "text": "ओके",
#       "timestamp": [
#         21.16,
#         21.84
#       ]
#     },
#     {
#       "text": "ओके",
#       "timestamp": [
#         22.08,
#         22.72
#       ]
#     },
#     {
#       "text": "ओके",
#       "timestamp": [
#         22.72,
#         22.92
#       ]
#     },
#     {
#       "text": "बस",
#       "timestamp": [
#         22.92,
#         23.36
#       ]
#     },
#     {
#       "text": "तनु",
#       "timestamp": [
#         23.36,
#         23.56
#       ]
#     },
#     {
#       "text": "यही",
#       "timestamp": [
#         23.56,
#         23.8
#       ]
#     },
#     {
#       "text": "पूछना",
#       "timestamp": [
#         23.8,
#         24.16
#       ]
#     },
#     {
#       "text": "थी",
#       "timestamp": [
#         24.16,
#         24.24
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         24.24,
#         24.44
#       ]
#     },
#     {
#       "text": "तनु",
#       "timestamp": [
#         24.44,
#         24.68
#       ]
#     },
#     {
#       "text": "सारी",
#       "timestamp": [
#         24.72,
#         25.08
#       ]
#     },
#     {
#       "text": "चीज़",
#       "timestamp": [
#         25.08,
#         25.24
#       ]
#     },
#     {
#       "text": "क्लियर",
#       "timestamp": [
#         25.28,
#         25.68
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         25.68,
#         25.8
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         25.8,
#         25.96
#       ]
#     },
#     {
#       "text": "कोई",
#       "timestamp": [
#         25.96,
#         26.16
#       ]
#     },
#     {
#       "text": "कॅन्फ़्यूज़न",
#       "timestamp": [
#         26.16,
#         26.8
#       ]
#     },
#     {
#       "text": "कोई",
#       "timestamp": [
#         26.8,
#         26.96
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         26.96,
#         27.4
#       ]
#     },
#     {
#       "text": "समझ",
#       "timestamp": [
#         27.4,
#         27.68
#       ]
#     },
#     {
#       "text": "आयी",
#       "timestamp": [
#         27.68,
#         27.88
#       ]
#     },
#     {
#       "text": "हो",
#       "timestamp": [
#         27.88,
#         28.04
#       ]
#     },
#     {
#       "text": "वे",
#       "timestamp": [
#         28.04,
#         28.2
#       ]
#     },
#     {
#       "text": "तो",
#       "timestamp": [
#         29.08,
#         29.2
#       ]
#     },
#     {
#       "text": "उसी",
#       "timestamp": [
#         29.64,
#         29.92
#       ]
#     },
#     {
#       "text": "में",
#       "timestamp": [
#         30.04,
#         30.16
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         36.08,
#         36.2
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         36.2,
#         36.44
#       ]
#     },
#     {
#       "text": "बीएन",
#       "timestamp": [
#         36.56,
#         36.84
#       ]
#     },
#     {
#       "text": "सिंह",
#       "timestamp": [
#         36.84,
#         37.08
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         37.08,
#         37.16
#       ]
#     },
#     {
#       "text": "ये",
#       "timestamp": [
#         37.16,
#         37.44
#       ]
#     },
#     {
#       "text": "पता",
#       "timestamp": [
#         37.44,
#         37.64
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         37.64,
#         37.72
#       ]
#     },
#     {
#       "text": "कि",
#       "timestamp": [
#         37.72,
#         37.84
#       ]
#     },
#     {
#       "text": "हुंडई",
#       "timestamp": [
#         37.84,
#         38.16
#       ]
#     },
#     {
#       "text": "जीने",
#       "timestamp": [
#         38.32,
#         38.64
#       ]
#     },
#     {
#       "text": "अपा",
#       "timestamp": [
#         38.64,
#         39.0
#       ]
#     },
#     {
#       "text": "खेतदेविच",
#       "timestamp": [
#         39.0,
#         39.84
#       ]
#     },
#     {
#       "text": "जदों",
#       "timestamp": [
#         40.04,
#         40.88
#       ]
#     },
#     {
#       "text": "चुना",
#       "timestamp": [
#         40.88,
#         41.32
#       ]
#     },
#     {
#       "text": "गोनिया",
#       "timestamp": [
#         41.32,
#         41.96
#       ]
#     },
#     {
#       "text": "था",
#       "timestamp": [
#         42.92,
#         43.28
#       ]
#     },
#     {
#       "text": "कई",
#       "timestamp": [
#         43.84,
#         44.12
#       ]
#     },
#     {
#       "text": "बारी",
#       "timestamp": [
#         44.12,
#         44.52
#       ]
#     },
#     {
#       "text": "आपा",
#       "timestamp": [
#         44.6,
#         44.88
#       ]
#     },
#     {
#       "text": "सताओ",
#       "timestamp": [
#         44.88,
#         45.24
#       ]
#     },
#     {
#       "text": "ऊपर",
#       "timestamp": [
#         45.24,
#         45.52
#       ]
#     },
#     {
#       "text": "सुखी",
#       "timestamp": [
#         45.52,
#         45.88
#       ]
#     },
#     {
#       "text": "देके",
#       "timestamp": [
#         45.88,
#         46.2
#       ]
#     },
#     {
#       "text": "न",
#       "timestamp": [
#         46.2,
#         46.32
#       ]
#     },
#     {
#       "text": "पर",
#       "timestamp": [
#         46.32,
#         46.48
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         46.48,
#         46.8
#       ]
#     },
#     {
#       "text": "लागने",
#       "timestamp": [
#         46.8,
#         47.32
#       ]
#     },
#     {
#       "text": "अंदर",
#       "timestamp": [
#         47.8,
#         48.64
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         48.72,
#         49.28
#       ]
#     },
#     {
#       "text": "दूजी",
#       "timestamp": [
#         50.6,
#         51.04
#       ]
#     },
#     {
#       "text": "का",
#       "timestamp": [
#         51.4,
#         52.04
#       ]
#     },
#     {
#       "text": "जो",
#       "timestamp": [
#         52.04,
#         52.16
#       ]
#     },
#     {
#       "text": "तो",
#       "timestamp": [
#         52.16,
#         52.32
#       ]
#     },
#     {
#       "text": "आप",
#       "timestamp": [
#         52.32,
#         52.48
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         52.48,
#         53.36
#       ]
#     },
#     {
#       "text": "ज्यादा",
#       "timestamp": [
#         53.36,
#         53.68
#       ]
#     },
#     {
#       "text": "देर",
#       "timestamp": [
#         53.68,
#         53.88
#       ]
#     },
#     {
#       "text": "खड़ा",
#       "timestamp": [
#         53.88,
#         54.2
#       ]
#     },
#     {
#       "text": "रख",
#       "timestamp": [
#         54.2,
#         54.44
#       ]
#     },
#     {
#       "text": "दिया",
#       "timestamp": [
#         54.44,
#         54.6
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         54.6,
#         54.68
#       ]
#     },
#     {
#       "text": "तो",
#       "timestamp": [
#         54.68,
#         54.8
#       ]
#     },
#     {
#       "text": "कुछ",
#       "timestamp": [
#         54.8,
#         55.0
#       ]
#     },
#     {
#       "text": "नोट",
#       "timestamp": [
#         55.04,
#         55.32
#       ]
#     },
#     {
#       "text": "गीता",
#       "timestamp": [
#         55.32,
#         55.6
#       ]
#     },
#     {
#       "text": "होना",
#       "timestamp": [
#         55.6,
#         56.04
#       ]
#     },
#     {
#       "text": "के",
#       "timestamp": [
#         56.4,
#         56.96
#       ]
#     },
#     {
#       "text": "बुलबुली",
#       "timestamp": [
#         57.0,
#         57.48
#       ]
#     },
#     {
#       "text": "उठ",
#       "timestamp": [
#         57.48,
#         57.64
#       ]
#     },
#     {
#       "text": "देने",
#       "timestamp": [
#         57.64,
#         57.92
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         57.92,
#         58.2
#       ]
#     },
#     {
#       "text": "देवी",
#       "timestamp": [
#         58.2,
#         58.52
#       ]
#     },
#     {
#       "text": "ओह",
#       "timestamp": [
#         58.52,
#         58.64
#       ]
#     },
#     {
#       "text": "मिथेन",
#       "timestamp": [
#         58.64,
#         59.12
#       ]
#     },
#     {
#       "text": "गैस",
#       "timestamp": [
#         59.12,
#         59.44
#       ]
#     },
#     {
#       "text": "फूँदी",
#       "timestamp": [
#         59.44,
#         61.04
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         61.04,
#         61.12
#       ]
#     },
#     {
#       "text": "मतलब",
#       "timestamp": [
#         61.12,
#         61.4
#       ]
#     },
#     {
#       "text": "अपा",
#       "timestamp": [
#         61.4,
#         61.6
#       ]
#     },
#     {
#       "text": "जीतने",
#       "timestamp": [
#         61.6,
#         61.88
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         61.88,
#         61.96
#       ]
#     },
#     {
#       "text": "इंसान",
#       "timestamp": [
#         61.96,
#         62.36
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         62.36,
#         62.48
#       ]
#     },
#     {
#       "text": "क्या",
#       "timestamp": [
#         62.52,
#         63.2
#       ]
#     },
#     {
#       "text": "जानवरानु",
#       "timestamp": [
#         63.44,
#         64.08
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         64.08,
#         64.28
#       ]
#     },
#     {
#       "text": "फसल",
#       "timestamp": [
#         64.28,
#         64.68
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         64.72,
#         64.84
#       ]
#     },
#     {
#       "text": "नुकसान",
#       "timestamp": [
#         64.84,
#         65.24
#       ]
#     },
#     {
#       "text": "पहुँचाउंगी",
#       "timestamp": [
#         65.24,
#         65.76
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         65.8,
#         66.0
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         66.32,
#         66.52
#       ]
#     },
#     {
#       "text": "ज्यादा",
#       "timestamp": [
#         66.52,
#         66.88
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         66.88,
#         67.24
#       ]
#     },
#     {
#       "text": "लान",
#       "timestamp": [
#         67.24,
#         67.52
#       ]
#     },
#     {
#       "text": "करके",
#       "timestamp": [
#         67.52,
#         68.84
#       ]
#     },
#     {
#       "text": "सेंसर",
#       "timestamp": [
#         69.52,
#         69.96
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         69.96,
#         70.28
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         70.28,
#         70.6
#       ]
#     },
#     {
#       "text": "देबीच",
#       "timestamp": [
#         70.6,
#         70.92
#       ]
#     },
#     {
#       "text": "लगेगा",
#       "timestamp": [
#         70.92,
#         71.48
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         71.64,
#         71.72
#       ]
#     },
#     {
#       "text": "देसी",
#       "timestamp": [
#         71.96,
#         72.36
#       ]
#     },
#     {
#       "text": "पाइप",
#       "timestamp": [
#         72.36,
#         73.6
#       ]
#     },
#     {
#       "text": "लग",
#       "timestamp": [
#         73.6,
#         73.84
#       ]
#     },
#     {
#       "text": "रहा",
#       "timestamp": [
#         73.84,
#         74.12
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         75.32,
#         75.4
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         75.4,
#         75.6
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         75.6,
#         75.92
#       ]
#     },
#     {
#       "text": "देबीच",
#       "timestamp": [
#         75.92,
#         76.24
#       ]
#     },
#     {
#       "text": "लग",
#       "timestamp": [
#         76.24,
#         76.48
#       ]
#     },
#     {
#       "text": "चुका",
#       "timestamp": [
#         76.48,
#         76.76
#       ]
#     },
#     {
#       "text": "वो",
#       "timestamp": [
#         76.76,
#         77.0
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         77.16,
#         77.44
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         77.44,
#         77.6
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         77.6,
#         77.88
#       ]
#     },
#     {
#       "text": "थोड़ी",
#       "timestamp": [
#         77.88,
#         78.16
#       ]
#     },
#     {
#       "text": "फसल",
#       "timestamp": [
#         78.16,
#         78.48
#       ]
#     },
#     {
#       "text": "को",
#       "timestamp": [
#         78.48,
#         78.72
#       ]
#     },
#     {
#       "text": "नुकसान",
#       "timestamp": [
#         78.72,
#         79.16
#       ]
#     },
#     {
#       "text": "होने",
#       "timestamp": [
#         79.24,
#         79.48
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         79.48,
#         79.76
#       ]
#     },
#     {
#       "text": "उन्हें",
#       "timestamp": [
#         79.76,
#         79.96
#       ]
#     },
#     {
#       "text": "ज्यादा",
#       "timestamp": [
#         79.96,
#         80.28
#       ]
#     },
#     {
#       "text": "जगह",
#       "timestamp": [
#         80.28,
#         80.52
#       ]
#     },
#     {
#       "text": "गैर",
#       "timestamp": [
#         80.52,
#         80.76
#       ]
#     },
#     {
#       "text": "नहीं",
#       "timestamp": [
#         80.76,
#         80.96
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         80.96,
#         81.2
#       ]
#     },
#     {
#       "text": "ठीक",
#       "timestamp": [
#         82.28,
#         82.52
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         82.52,
#         82.6
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         82.6,
#         82.76
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         82.92,
#         83.08
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         83.08,
#         83.36
#       ]
#     },
#     {
#       "text": "फ़ोन",
#       "timestamp": [
#         83.36,
#         83.68
#       ]
#     },
#     {
#       "text": "से",
#       "timestamp": [
#         83.68,
#         83.8
#       ]
#     },
#     {
#       "text": "वाला",
#       "timestamp": [
#         83.8,
#         84.04
#       ]
#     },
#     {
#       "text": "अटैच",
#       "timestamp": [
#         84.04,
#         84.32
#       ]
#     },
#     {
#       "text": "हो",
#       "timestamp": [
#         84.4,
#         84.52
#       ]
#     },
#     {
#       "text": "चुका",
#       "timestamp": [
#         84.52,
#         84.76
#       ]
#     },
#     {
#       "text": "जो",
#       "timestamp": [
#         84.76,
#         85.08
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         85.08,
#         85.4
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         85.4,
#         85.76
#       ]
#     },
#     {
#       "text": "में",
#       "timestamp": [
#         85.76,
#         85.88
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         85.88,
#         86.28
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         86.28,
#         86.36
#       ]
#     },
#     {
#       "text": "लोड",
#       "timestamp": [
#         86.36,
#         86.6
#       ]
#     },
#     {
#       "text": "होगी",
#       "timestamp": [
#         86.6,
#         87.16
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         87.32,
#         87.6
#       ]
#     },
#     {
#       "text": "फ़ोन",
#       "timestamp": [
#         87.6,
#         87.88
#       ]
#     },
#     {
#       "text": "पे",
#       "timestamp": [
#         87.88,
#         88.0
#       ]
#     },
#     {
#       "text": "मैसेज",
#       "timestamp": [
#         88.0,
#         88.36
#       ]
#     },
#     {
#       "text": "आना",
#       "timestamp": [
#         88.36,
#         88.56
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         88.56,
#         88.64
#       ]
#     },
#     {
#       "text": "सिंह",
#       "timestamp": [
#         88.96,
#         89.16
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         89.16,
#         89.36
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         89.36,
#         89.64
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         89.64,
#         89.96
#       ]
#     },
#     {
#       "text": "देवी",
#       "timestamp": [
#         89.96,
#         90.24
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         90.4,
#         90.76
#       ]
#     },
#     {
#       "text": "दी",
#       "timestamp": [
#         90.76,
#         90.88
#       ]
#     },
#     {
#       "text": "नमी",
#       "timestamp": [
#         90.88,
#         91.36
#       ]
#     },
#     {
#       "text": "ये",
#       "timestamp": [
#         91.48,
#         91.68
#       ]
#     },
#     {
#       "text": "नमी",
#       "timestamp": [
#         91.68,
#         92.0
#       ]
#     },
#     {
#       "text": "दी",
#       "timestamp": [
#         92.0,
#         92.12
#       ]
#     },
#     {
#       "text": "मात्रा",
#       "timestamp": [
#         92.12,
#         92.52
#       ]
#     },
#     {
#       "text": "काट",
#       "timestamp": [
#         92.52,
#         92.76
#       ]
#     },
#     {
#       "text": "गई",
#       "timestamp": [
#         92.76,
#         92.96
#       ]
#     },
#     {
#       "text": "ये",
#       "timestamp": [
#         92.96,
#         93.08
#       ]
#     },
#     {
#       "text": "कृपा",
#       "timestamp": [
#         93.08,
#         93.44
#       ]
#     },
#     {
#       "text": "मोटर",
#       "timestamp": [
#         93.44,
#         93.76
#       ]
#     },
#     {
#       "text": "चला",
#       "timestamp": [
#         93.76,
#         94.04
#       ]
#     },
#     {
#       "text": "दो",
#       "timestamp": [
#         94.04,
#         94.28
#       ]
#     },
#     {
#       "text": "ठीक",
#       "timestamp": [
#         95.92,
#         96.16
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         96.16,
#         96.32
#       ]
#     },
#     {
#       "text": "जो",
#       "timestamp": [
#         96.56,
#         96.8
#       ]
#     },
#     {
#       "text": "दो",
#       "timestamp": [
#         96.8,
#         96.96
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         96.96,
#         97.24
#       ]
#     },
#     {
#       "text": "देवी",
#       "timestamp": [
#         97.24,
#         97.48
#       ]
#     },
#     {
#       "text": "से",
#       "timestamp": [
#         97.52,
#         97.6
#       ]
#     },
#     {
#       "text": "नमी",
#       "timestamp": [
#         97.6,
#         97.88
#       ]
#     },
#     {
#       "text": "दी",
#       "timestamp": [
#         97.88,
#         98.0
#       ]
#     },
#     {
#       "text": "मात्रा",
#       "timestamp": [
#         98.0,
#         98.4
#       ]
#     },
#     {
#       "text": "पूरी",
#       "timestamp": [
#         98.4,
#         98.68
#       ]
#     },
#     {
#       "text": "होगी",
#       "timestamp": [
#         98.68,
#         99.2
#       ]
#     },
#     {
#       "text": "थोड़ी",
#       "timestamp": [
#         99.56,
#         99.84
#       ]
#     },
#     {
#       "text": "सी",
#       "timestamp": [
#         103.04,
#         103.24
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         103.36,
#         103.8
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         103.8,
#         103.92
#       ]
#     },
#     {
#       "text": "बचत",
#       "timestamp": [
#         103.92,
#         104.2
#       ]
#     },
#     {
#       "text": "हुई",
#       "timestamp": [
#         104.2,
#         104.56
#       ]
#     },
#     {
#       "text": "एक",
#       "timestamp": [
#         105.0,
#         105.12
#       ]
#     },
#     {
#       "text": "अपने",
#       "timestamp": [
#         105.12,
#         105.36
#       ]
#     },
#     {
#       "text": "समय",
#       "timestamp": [
#         105.36,
#         105.72
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         105.72,
#         105.84
#       ]
#     },
#     {
#       "text": "बचत",
#       "timestamp": [
#         105.84,
#         106.12
#       ]
#     },
#     {
#       "text": "हुई",
#       "timestamp": [
#         106.12,
#         106.32
#       ]
#     },
#     {
#       "text": "कई",
#       "timestamp": [
#         106.32,
#         106.52
#       ]
#     },
#     {
#       "text": "बार",
#       "timestamp": [
#         106.52,
#         106.68
#       ]
#     },
#     {
#       "text": "ही",
#       "timestamp": [
#         106.68,
#         106.76
#       ]
#     },
#     {
#       "text": "जीना",
#       "timestamp": [
#         106.8,
#         107.16
#       ]
#     },
#     {
#       "text": "दे",
#       "timestamp": [
#         107.16,
#         107.28
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         107.28,
#         107.6
#       ]
#     },
#     {
#       "text": "हो",
#       "timestamp": [
#         107.6,
#         107.68
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         107.68,
#         107.76
#       ]
#     },
#     {
#       "text": "दे",
#       "timestamp": [
#         107.76,
#         107.88
#       ]
#     },
#     {
#       "text": "करा",
#       "timestamp": [
#         107.88,
#         108.12
#       ]
#     },
#     {
#       "text": "तो",
#       "timestamp": [
#         108.12,
#         108.24
#       ]
#     },
#     {
#       "text": "दूर",
#       "timestamp": [
#         108.24,
#         108.52
#       ]
#     },
#     {
#       "text": "नहीं",
#       "timestamp": [
#         108.52,
#         108.68
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         108.68,
#         108.88
#       ]
#     },
#     {
#       "text": "उन्होंने",
#       "timestamp": [
#         109.16,
#         109.48
#       ]
#     },
#     {
#       "text": "बार",
#       "timestamp": [
#         109.48,
#         109.76
#       ]
#     },
#     {
#       "text": "बार",
#       "timestamp": [
#         109.76,
#         109.92
#       ]
#     },
#     {
#       "text": "देखने",
#       "timestamp": [
#         109.92,
#         110.28
#       ]
#     },
#     {
#       "text": "जाना",
#       "timestamp": [
#         110.28,
#         110.72
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         110.8,
#         110.92
#       ]
#     },
#     {
#       "text": "पर",
#       "timestamp": [
#         110.92,
#         111.16
#       ]
#     },
#     {
#       "text": "गया",
#       "timestamp": [
#         111.16,
#         111.4
#       ]
#     },
#     {
#       "text": "कि",
#       "timestamp": [
#         111.44,
#         111.56
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         111.56,
#         111.96
#       ]
#     },
#     {
#       "text": "बंदा",
#       "timestamp": [
#         112.0,
#         112.4
#       ]
#     },
#     {
#       "text": "करना",
#       "timestamp": [
#         112.4,
#         112.8
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         112.8,
#         112.92
#       ]
#     },
#     {
#       "text": "कदु",
#       "timestamp": [
#         112.92,
#         113.2
#       ]
#     },
#     {
#       "text": "करना",
#       "timestamp": [
#         113.2,
#         113.52
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         113.52,
#         113.6
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         113.6,
#         113.72
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         113.72,
#         113.92
#       ]
#     },
#     {
#       "text": "इतना",
#       "timestamp": [
#         114.72,
#         115.0
#       ]
#     },
#     {
#       "text": "समय",
#       "timestamp": [
#         115.0,
#         115.32
#       ]
#     },
#     {
#       "text": "बच",
#       "timestamp": [
#         115.32,
#         115.52
#       ]
#     },
#     {
#       "text": "गया",
#       "timestamp": [
#         115.52,
#         115.72
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         115.72,
#         116.0
#       ]
#     },
#     {
#       "text": "बेशक",
#       "timestamp": [
#         116.96,
#         117.4
#       ]
#     },
#     {
#       "text": "अपन",
#       "timestamp": [
#         117.4,
#         117.68
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         117.68,
#         118.16
#       ]
#     },
#     {
#       "text": "पे",
#       "timestamp": [
#         118.16,
#         118.24
#       ]
#     },
#     {
#       "text": "या",
#       "timestamp": [
#         118.24,
#         118.44
#       ]
#     },
#     {
#       "text": "बिजली",
#       "timestamp": [
#         118.44,
#         118.84
#       ]
#     },
#     {
#       "text": "पे",
#       "timestamp": [
#         118.84,
#         119.04
#       ]
#     },
#     {
#       "text": "सब्सिडी",
#       "timestamp": [
#         119.04,
#         119.52
#       ]
#     },
#     {
#       "text": "मिल",
#       "timestamp": [
#         119.52,
#         119.72
#       ]
#     },
#     {
#       "text": "रही",
#       "timestamp": [
#         119.72,
#         119.92
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         119.92,
#         120.08
#       ]
#     },
#     {
#       "text": "मोटर",
#       "timestamp": [
#         120.4,
#         120.92
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         120.92,
#         121.04
#       ]
#     },
#     {
#       "text": "मेंटेनेंस",
#       "timestamp": [
#         121.04,
#         121.56
#       ]
#     },
#     {
#       "text": "पे",
#       "timestamp": [
#         121.56,
#         121.64
#       ]
#     },
#     {
#       "text": "खर्चा",
#       "timestamp": [
#         121.64,
#         121.96
#       ]
#     },
#     {
#       "text": "तो",
#       "timestamp": [
#         121.96,
#         122.04
#       ]
#     },
#     {
#       "text": "आपका",
#       "timestamp": [
#         122.04,
#         122.28
#       ]
#     },
#     {
#       "text": "ही",
#       "timestamp": [
#         122.28,
#         122.36
#       ]
#     },
#     {
#       "text": "लोन",
#       "timestamp": [
#         122.36,
#         122.6
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         122.6,
#         122.72
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         122.72,
#         123.0
#       ]
#     },
#     {
#       "text": "जितनी",
#       "timestamp": [
#         123.76,
#         124.16
#       ]
#     },
#     {
#       "text": "ज्यादा",
#       "timestamp": [
#         124.16,
#         124.48
#       ]
#     },
#     {
#       "text": "मोटर",
#       "timestamp": [
#         124.48,
#         124.8
#       ]
#     },
#     {
#       "text": "चलोगी",
#       "timestamp": [
#         124.8,
#         125.28
#       ]
#     },
#     {
#       "text": "ओनली",
#       "timestamp": [
#         125.32,
#         125.52
#       ]
#     },
#     {
#       "text": "जल्दी",
#       "timestamp": [
#         125.52,
#         125.8
#       ]
#     },
#     {
#       "text": "खराब",
#       "timestamp": [
#         125.8,
#         126.08
#       ]
#     },
#     {
#       "text": "होगी",
#       "timestamp": [
#         126.08,
#         126.36
#       ]
#     },
#     {
#       "text": "ओनली",
#       "timestamp": [
#         126.36,
#         126.6
#       ]
#     },
#     {
#       "text": "जल्दी",
#       "timestamp": [
#         126.6,
#         126.84
#       ]
#     },
#     {
#       "text": "रबड़",
#       "timestamp": [
#         126.84,
#         127.08
#       ]
#     },
#     {
#       "text": "की",
#       "timestamp": [
#         127.08,
#         127.68
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         128.2,
#         128.28
#       ]
#     },
#     {
#       "text": "ना",
#       "timestamp": [
#         128.28,
#         128.68
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         129.0,
#         129.16
#       ]
#     },
#     {
#       "text": "कुल्लू",
#       "timestamp": [
#         129.16,
#         129.44
#       ]
#     },
#     {
#       "text": "बनाके",
#       "timestamp": [
#         129.44,
#         129.96
#       ]
#     },
#     {
#       "text": "जोड़ा",
#       "timestamp": [
#         129.96,
#         130.2
#       ]
#     },
#     {
#       "text": "हेगा",
#       "timestamp": [
#         130.2,
#         130.68
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         130.68,
#         130.88
#       ]
#     },
#     {
#       "text": "थोड़ा",
#       "timestamp": [
#         130.88,
#         131.28
#       ]
#     },
#     {
#       "text": "सा",
#       "timestamp": [
#         131.28,
#         131.6
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         131.6,
#         131.76
#       ]
#     },
#     {
#       "text": "बचूगा",
#       "timestamp": [
#         131.76,
#         132.2
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         132.2,
#         132.52
#       ]
#     },
#     {
#       "text": "बिजली",
#       "timestamp": [
#         132.84,
#         133.28
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         133.28,
#         133.4
#       ]
#     },
#     {
#       "text": "बचूगी",
#       "timestamp": [
#         133.4,
#         133.92
#       ]
#     },
#     {
#       "text": "पानी",
#       "timestamp": [
#         133.92,
#         134.28
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         134.28,
#         134.4
#       ]
#     },
#     {
#       "text": "बचूगा",
#       "timestamp": [
#         134.4,
#         134.96
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         134.96,
#         135.16
#       ]
#     },
#     {
#       "text": "जोड़े",
#       "timestamp": [
#         135.16,
#         135.48
#       ]
#     },
#     {
#       "text": "खेत",
#       "timestamp": [
#         135.48,
#         136.08
#       ]
#     },
#     {
#       "text": "में",
#       "timestamp": [
#         136.08,
#         136.2
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         136.24,
#         136.36
#       ]
#     },
#     {
#       "text": "खेती",
#       "timestamp": [
#         136.48,
#         136.92
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         136.92,
#         137.04
#       ]
#     },
#     {
#       "text": "पैदावार",
#       "timestamp": [
#         137.04,
#         137.64
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         137.64,
#         137.76
#       ]
#     },
#     {
#       "text": "यानी",
#       "timestamp": [
#         137.76,
#         138.0
#       ]
#     },
#     {
#       "text": "थोड़े",
#       "timestamp": [
#         138.0,
#         138.24
#       ]
#     },
#     {
#       "text": "चौबीस",
#       "timestamp": [
#         138.24,
#         139.0
#       ]
#     },
#     {
#       "text": "पैदावार",
#       "timestamp": [
#         139.0,
#         139.44
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         139.44,
#         139.52
#       ]
#     },
#     {
#       "text": "और",
#       "timestamp": [
#         139.52,
#         139.68
#       ]
#     },
#     {
#       "text": "भी",
#       "timestamp": [
#         139.68,
#         139.84
#       ]
#     },
#     {
#       "text": "बचूगी",
#       "timestamp": [
#         139.84,
#         140.36
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         141.2,
#         141.28
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         141.36,
#         141.44
#       ]
#     },
#     {
#       "text": "ठीक",
#       "timestamp": [
#         142.24,
#         142.44
#       ]
#     },
#     {
#       "text": "है",
#       "timestamp": [
#         142.44,
#         142.52
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         143.48,
#         143.6
#       ]
#     },
#     {
#       "text": "हाँ",
#       "timestamp": [
#         144.0,
#         144.24
#       ]
#     },
#     {
#       "text": "जी",
#       "timestamp": [
#         144.24,
#         144.36
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         144.36,
#         144.52
#       ]
#     },
#     {
#       "text": "समा",
#       "timestamp": [
#         144.52,
#         144.76
#       ]
#     },
#     {
#       "text": "देने",
#       "timestamp": [
#         144.76,
#         145.0
#       ]
#     },
#     {
#       "text": "में",
#       "timestamp": [
#         145.0,
#         145.08
#       ]
#     },
#     {
#       "text": "से",
#       "timestamp": [
#         145.12,
#         145.2
#       ]
#     },
#     {
#       "text": "थोड़ा",
#       "timestamp": [
#         145.24,
#         145.44
#       ]
#     },
#     {
#       "text": "बहुत",
#       "timestamp": [
#         145.44,
#         145.64
#       ]
#     },
#     {
#       "text": "बहुत",
#       "timestamp": [
#         145.64,
#         145.84
#       ]
#     },
#     {
#       "text": "धन्यवाद",
#       "timestamp": [
#         145.84,
#         146.52
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         146.56,
#         146.68
#       ]
#     },
#     {
#       "text": "ओके",
#       "timestamp": [
#         147.08,
#         147.28
#       ]
#     },
#     {
#       "text": "थैंक",
#       "timestamp": [
#         147.28,
#         147.44
#       ]
#     },
#     {
#       "text": "यू",
#       "timestamp": [
#         147.44,
#         147.52
#       ]
#     },
#     {
#       "text": "मैडम",
#       "timestamp": [
#         147.64,
#         147.84
#       ]
#     },
#     {
#       "text": "ओके",
#       "timestamp": [
#         148.04,
#         148.28
#       ]
#     },
#     {
#       "text": "सर",
#       "timestamp": [
#         148.28,
#         148.96
#       ]
#     }
#   ]
# }

# %%
response= submit_transcription(API_URL, HEADERS, AUDIO_FILE_PATH, PAYLOAD_DATA)
# Out:
# Status code: 200
# Response JSON: {'task_id': '1b9c73f682c540d7b58f63dd0c5972c1', 'dataset_id': '1f5f5f971e8b4a59bd7edb1069611160', 'status': 'PENDING', 'skipped_file': []}

# %%
result_data = poll_status(response.get("task_id"))
# Out:
# Polling attempt 1, Status Code: 200
# Current status: PENDING
# Polling attempt 2, Status Code: 200
# Current status: PENDING
# Polling attempt 3, Status Code: 200
# Current status: COMPLETED

# %%
result_data
# Out:
# {'status': 'COMPLETED',
#  'responses': [{'id': 'd1e662fc2b4d4f589977f014c25d3c86',
#    'task_id': '1b9c73f682c540d7b58f63dd0c5972c1',
#    'response': {'output': {'transcriptions': [{'source': 'https://karyaaisa.blob.core.windows.net/langserver/audio_7c6e60d69dab4a4fb571d74747d2910e.wav?st=2025-07-27T13%3A35%3A21Z&se=2025-07-28T13%3A35%3A21Z&sp=r&sv=2023-11-03&sr=b&sig=7lqjmDl80PQxFDUI6ab0lJWQ%2B7WfAtL1tNEBrEDeKLY%3D',
#        'duration': 'PT2M30.6S',
#        'timestamp': '2025-07-27T13:35:51Z',
#        'durationInTicks': 1506000000,
#        'recognizedPhrases': [{'nBest': [{'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354302,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.551557,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781765,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048783,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.5811583,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.4616028,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751822,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136235,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991724,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.8268918,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614266,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8664881,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'कल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10043929,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.74404544,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7979985,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.3168954,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.1551322,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'को',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.12S',
#              'confidence': 0.1425455,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 120},
#             {'word': 'ना',
#              'offset': 'PT12.56S',
#              'duration': 'PT0.16S',
#              'confidence': 0.117057525,
#              'offsetInTicks': 125600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 12560,
#              'durationMilliseconds': 160},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.54721934,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.35077906,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.50296366,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.7872108,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.62966824,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.13587242,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर।',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर।',
#            'confidence': 0.50449187},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354302,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.551557,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781765,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048783,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.5811583,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.4616028,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751822,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136235,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991724,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.8268918,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614266,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8664881,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'गल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.11122753,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.9320308,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7692381,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.32034338,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.16068487,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'को',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.12S',
#              'confidence': 0.14789782,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 120},
#             {'word': 'ना',
#              'offset': 'PT12.56S',
#              'duration': 'PT0.16S',
#              'confidence': 0.11307252,
#              'offsetInTicks': 125600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 12560,
#              'durationMilliseconds': 160},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.51886654,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.33332315,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.50032884,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.79459065,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.6198647,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.13423508,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'confidence': 0.5083669},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354306,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.55155706,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781767,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048784,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.58115834,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.46160287,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751824,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136265,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991753,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.82689226,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614275,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.86648834,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'गल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.11122753,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.932031,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7692384,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.32034338,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.16068484,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'के',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.08S',
#              'confidence': 0.048774496,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 80},
#             {'word': 'लिए',
#              'offset': 'PT12.48S',
#              'duration': 'PT0.44S',
#              'confidence': 0.1416222,
#              'offsetInTicks': 124800000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 12480,
#              'durationMilliseconds': 440},
#             {'word': 'ना',
#              'offset': 'PT12.92S',
#              'duration': 'PT0.08S',
#              'confidence': 0.3017459,
#              'offsetInTicks': 129200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 12920,
#              'durationMilliseconds': 80},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.5469415,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.33998123,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.49781072,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.7892813,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.62477577,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.12325713,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'confidence': 0.5008271},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354306,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.55155706,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781767,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612266,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.7048784,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.58115834,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT7.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.46160287,
#              'offsetInTicks': 79600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 7960,
#              'durationMilliseconds': 160},
#             {'word': 'जी',
#              'offset': 'PT8.12S',
#              'duration': 'PT0.12S',
#              'confidence': 0.72985035,
#              'offsetInTicks': 81200000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 8120,
#              'durationMilliseconds': 120},
#             {'word': 'देव',
#              'offset': 'PT8.92S',
#              'duration': 'PT0.16S',
#              'confidence': 0.15332341,
#              'offsetInTicks': 89200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 8920,
#              'durationMilliseconds': 160},
#             {'word': 'सिंह',
#              'offset': 'PT9.12S',
#              'duration': 'PT0.2S',
#              'confidence': 0.3751824,
#              'offsetInTicks': 91200000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 9120,
#              'durationMilliseconds': 200},
#             {'word': 'जी',
#              'offset': 'PT9.32S',
#              'duration': 'PT0.08S',
#              'confidence': 0.786756,
#              'offsetInTicks': 93200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 9320,
#              'durationMilliseconds': 80},
#             {'word': 'मैं',
#              'offset': 'PT9.4S',
#              'duration': 'PT0.16S',
#              'confidence': 0.78136265,
#              'offsetInTicks': 94000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 9400,
#              'durationMilliseconds': 160},
#             {'word': 'कल्टीवेट',
#              'offset': 'PT9.56S',
#              'duration': 'PT0.48S',
#              'confidence': 0.65991753,
#              'offsetInTicks': 95600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 9560,
#              'durationMilliseconds': 480},
#             {'word': 'कंपनी',
#              'offset': 'PT10.04S',
#              'duration': 'PT0.4S',
#              'confidence': 0.82689226,
#              'offsetInTicks': 100400000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 10040,
#              'durationMilliseconds': 400},
#             {'word': 'पटियाले',
#              'offset': 'PT10.44S',
#              'duration': 'PT0.44S',
#              'confidence': 0.42614275,
#              'offsetInTicks': 104400000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 10440,
#              'durationMilliseconds': 440},
#             {'word': 'तो',
#              'offset': 'PT10.88S',
#              'duration': 'PT0.12S',
#              'confidence': 0.86648834,
#              'offsetInTicks': 108800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 10880,
#              'durationMilliseconds': 120},
#             {'word': 'गल',
#              'offset': 'PT11S',
#              'duration': 'PT0.2S',
#              'confidence': 0.11122753,
#              'offsetInTicks': 110000000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 11000,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT11.2S',
#              'duration': 'PT0.16S',
#              'confidence': 0.932031,
#              'offsetInTicks': 112000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 11200,
#              'durationMilliseconds': 160},
#             {'word': 'रही',
#              'offset': 'PT11.36S',
#              'duration': 'PT0.28S',
#              'confidence': 0.7692384,
#              'offsetInTicks': 113600000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 11360,
#              'durationMilliseconds': 280},
#             {'word': 'है',
#              'offset': 'PT11.72S',
#              'duration': 'PT0.08S',
#              'confidence': 0.32034338,
#              'offsetInTicks': 117200000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 11720,
#              'durationMilliseconds': 80},
#             {'word': 'थोड़े',
#              'offset': 'PT12.08S',
#              'duration': 'PT0.32S',
#              'confidence': 0.16068484,
#              'offsetInTicks': 120800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 12080,
#              'durationMilliseconds': 320},
#             {'word': 'को',
#              'offset': 'PT12.4S',
#              'duration': 'PT0.08S',
#              'confidence': 0.14789785,
#              'offsetInTicks': 124000000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 12400,
#              'durationMilliseconds': 80},
#             {'word': 'ले',
#              'offset': 'PT12.48S',
#              'duration': 'PT0.12S',
#              'confidence': 0.025268108,
#              'offsetInTicks': 124800000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12480,
#              'durationMilliseconds': 120},
#             {'word': 'ना',
#              'offset': 'PT12.6S',
#              'duration': 'PT0.12S',
#              'confidence': 0.44332874,
#              'offsetInTicks': 126000000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 12600,
#              'durationMilliseconds': 120},
#             {'word': 'लड़का',
#              'offset': 'PT13.68S',
#              'duration': 'PT0.32S',
#              'confidence': 0.5204434,
#              'offsetInTicks': 136800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 13680,
#              'durationMilliseconds': 320},
#             {'word': 'आया',
#              'offset': 'PT14S',
#              'duration': 'PT0.28S',
#              'confidence': 0.32141152,
#              'offsetInTicks': 140000000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 14000,
#              'durationMilliseconds': 280},
#             {'word': 'उन्होंने',
#              'offset': 'PT14.36S',
#              'duration': 'PT0.36S',
#              'confidence': 0.49334845,
#              'offsetInTicks': 143600000.0,
#              'durationInTicks': 3600000.0,
#              'offsetMilliseconds': 14360,
#              'durationMilliseconds': 360},
#             {'word': 'कार्बन',
#              'offset': 'PT14.72S',
#              'duration': 'PT0.44S',
#              'confidence': 0.7887503,
#              'offsetInTicks': 147200000.0,
#              'durationInTicks': 4400000.0,
#              'offsetMilliseconds': 14720,
#              'durationMilliseconds': 440},
#             {'word': 'प्रोग्राम',
#              'offset': 'PT15.2S',
#              'duration': 'PT0.4S',
#              'confidence': 0.61688095,
#              'offsetInTicks': 152000000.0,
#              'durationInTicks': 4000000.0,
#              'offsetMilliseconds': 15200,
#              'durationMilliseconds': 400},
#             {'word': 'पर',
#              'offset': 'PT15.6S',
#              'duration': 'PT0.32S',
#              'confidence': 0.1289646,
#              'offsetInTicks': 156000000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 15600,
#              'durationMilliseconds': 320}],
#            'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े को ले ना लड़का आया उन्होंने कार्बन प्रोग्राम पर',
#            'confidence': 0.50294775},
#           {'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो गल कर रही है थोड़े के लिए ना लड़का आया उन्होंने कार्बन प्रोग्राम बार',
#            'words': [{'word': 'हैलो',
#              'offset': 'PT2.32S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8354302,
#              'offsetInTicks': 23200000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2320,
#              'durationMilliseconds': 160},
#             {'word': 'हैलो',
#              'offset': 'PT2.48S',
#              'duration': 'PT0.16S',
#              'confidence': 0.551557,
#              'offsetInTicks': 24800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 2480,
#              'durationMilliseconds': 160},
#             {'word': 'हाँ',
#              'offset': 'PT4.84S',
#              'duration': 'PT0.12S',
#              'confidence': 0.8781765,
#              'offsetInTicks': 48400000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 4840,
#              'durationMilliseconds': 120},
#             {'word': 'जी',
#              'offset': 'PT4.96S',
#              'duration': 'PT0.2S',
#              'confidence': 0.9612267,
#              'offsetInTicks': 49600000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 4960,
#              'durationMilliseconds': 200},
#             {'word': 'सस्तिकल',
#              'offset': 'PT5.16S',
#              'duration': 'PT0.52S',
#              'confidence': 0.116050765,
#              'offsetInTicks': 51600000.0,
#              'durationInTicks': 5200000.0,
#              'offsetMilliseconds': 5160,
#              'durationMilliseconds': 520},
#             {'word': 'जी',
#              'offset': 'PT5.68S',
#              'duration': 'PT0.2S',
#              'confidence': 0.70487833,
#              'offsetInTicks': 56800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 5680,
#              'durationMilliseconds': 200},
#             {'word': 'कल',
#              'offset': 'PT6.44S',
#              'duration': 'PT0.2S',
#              'confidence': 0.10360378,
#              'offsetInTicks': 64400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 6440,
#              'durationMilliseconds': 200},
#             {'word': 'कर',
#              'offset': 'PT6.64S',
#              'duration': 'PT0.16S',
#              'confidence': 0.35214725,
#              'offsetInTicks': 66400000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6640,
#              'durationMilliseconds': 160},
#             {'word': 'रहे',
#              'offset': 'PT6.8S',
#              'duration': 'PT0.16S',
#              'confidence': 0.5811583,
#              'offsetInTicks': 68000000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6800,
#              'durationMilliseconds': 160},
#             {'word': 'थे',
#              'offset': 'PT6.96S',
#              'duration': 'PT0.16S',
#              'confidence': 0.16865757,
#              'offsetInTicks': 69600000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 6960,
# ...
#              'offset': 'PT2M25.64S',
#              'duration': 'PT0.2S',
#              'confidence': 0.5073979,
#              'offsetInTicks': 1456400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 145640,
#              'durationMilliseconds': 200},
#             {'word': 'धन्यवाद',
#              'offset': 'PT2M25.84S',
#              'duration': 'PT0.68S',
#              'confidence': 0.5447692,
#              'offsetInTicks': 1458400000.0,
#              'durationInTicks': 6800000.0,
#              'offsetMilliseconds': 145840,
#              'durationMilliseconds': 680},
#             {'word': 'सर',
#              'offset': 'PT2M26.56S',
#              'duration': 'PT0.12S',
#              'confidence': 0.47606575,
#              'offsetInTicks': 1465600000.0,
#              'durationInTicks': 1200000.0,
#              'offsetMilliseconds': 146560,
#              'durationMilliseconds': 120},
#             {'word': 'ओके',
#              'offset': 'PT2M27.08S',
#              'duration': 'PT0.2S',
#              'confidence': 0.59440196,
#              'offsetInTicks': 1470800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 147080,
#              'durationMilliseconds': 200},
#             {'word': 'थैंक',
#              'offset': 'PT2M27.28S',
#              'duration': 'PT0.16S',
#              'confidence': 0.8798975,
#              'offsetInTicks': 1472800000.0,
#              'durationInTicks': 1600000.0,
#              'offsetMilliseconds': 147280,
#              'durationMilliseconds': 160},
#             {'word': 'यू',
#              'offset': 'PT2M27.44S',
#              'duration': 'PT0.08S',
#              'confidence': 0.53551394,
#              'offsetInTicks': 1474400000.0,
#              'durationInTicks': 800000.0,
#              'offsetMilliseconds': 147440,
#              'durationMilliseconds': 80},
#             {'word': 'मैडम',
#              'offset': 'PT2M27.64S',
#              'duration': 'PT0.2S',
#              'confidence': 0.31638944,
#              'offsetInTicks': 1476400000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 147640,
#              'durationMilliseconds': 200}],
#            'display': 'सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समय देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम',
#            'lexical': 'सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समय देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम',
#            'maskedITN': 'सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समय देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम',
#            'confidence': 0.4734029}],
#          'offset': 'PT2M9S',
#          'channel': 0,
#          'duration': 'PT18.84S',
#          'offsetInTicks': 1290000000.0,
#          'durationInTicks': 188400000.0,
#          'recognitionStatus': 'Success',
#          'offsetMilliseconds': 129000,
#          'durationMilliseconds': 18840},
#         {'nBest': [{'itn': 'ओके सर',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.68S',
#              'confidence': 0.836343,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 6800000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 680}],
#            'display': 'ओके सर।',
#            'lexical': 'ओके सर',
#            'maskedITN': 'ओके सर।',
#            'confidence': 0.8227327},
#           {'itn': 'ओके सर सस्ती का',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.2S',
#              'confidence': 0.836343,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 200},
#             {'word': 'सस्ती',
#              'offset': 'PT2M28.48S',
#              'duration': 'PT0.28S',
#              'confidence': 0.10090179,
#              'offsetInTicks': 1484800000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 148480,
#              'durationMilliseconds': 280},
#             {'word': 'का',
#              'offset': 'PT2M28.76S',
#              'duration': 'PT0.48S',
#              'confidence': 0.101739444,
#              'offsetInTicks': 1487600000.0,
#              'durationInTicks': 4800000.0,
#              'offsetMilliseconds': 148760,
#              'durationMilliseconds': 480}],
#            'display': 'ओके सर सस्ती का',
#            'lexical': 'ओके सर सस्ती का',
#            'maskedITN': 'ओके सर सस्ती का',
#            'confidence': 0.46202666},
#           {'itn': 'ओके सर सस्ती',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.32S',
#              'confidence': 0.836343,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 3200000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 320},
#             {'word': 'सस्ती',
#              'offset': 'PT2M28.6S',
#              'duration': 'PT0.56S',
#              'confidence': 0.10090179,
#              'offsetInTicks': 1486000000.0,
#              'durationInTicks': 5600000.0,
#              'offsetMilliseconds': 148600,
#              'durationMilliseconds': 560}],
#            'display': 'ओके सर सस्ती',
#            'lexical': 'ओके सर सस्ती',
#            'maskedITN': 'ओके सर सस्ती',
#            'confidence': 0.58212245},
#           {'itn': 'ओके सर सस्ती कल',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.24S',
#              'confidence': 0.80912304,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 240},
#             {'word': 'सर',
#              'offset': 'PT2M28.28S',
#              'duration': 'PT0.2S',
#              'confidence': 0.83634305,
#              'offsetInTicks': 1482800000.0,
#              'durationInTicks': 2000000.0,
#              'offsetMilliseconds': 148280,
#              'durationMilliseconds': 200},
#             {'word': 'सस्ती',
#              'offset': 'PT2M28.48S',
#              'duration': 'PT0.28S',
#              'confidence': 0.10090179,
#              'offsetInTicks': 1484800000.0,
#              'durationInTicks': 2800000.0,
#              'offsetMilliseconds': 148480,
#              'durationMilliseconds': 280},
#             {'word': 'कल',
#              'offset': 'PT2M28.76S',
#              'duration': 'PT0.24S',
#              'confidence': 0.0028936125,
#              'offsetInTicks': 1487600000.0,
#              'durationInTicks': 2400000.0,
#              'offsetMilliseconds': 148760,
#              'durationMilliseconds': 240}],
#            'display': 'ओके सर सस्ती कल',
#            'lexical': 'ओके सर सस्ती कल',
#            'maskedITN': 'ओके सर सस्ती कल',
#            'confidence': 0.43731537},
#           {'itn': 'ओके',
#            'words': [{'word': 'ओके',
#              'offset': 'PT2M28.04S',
#              'duration': 'PT0.84S',
#              'confidence': 0.8091224,
#              'offsetInTicks': 1480400000.0,
#              'durationInTicks': 8400000.0,
#              'offsetMilliseconds': 148040,
#              'durationMilliseconds': 840}],
#            'display': 'ओके',
#            'lexical': 'ओके',
#            'maskedITN': 'ओके',
#            'confidence': 0.8091224}],
#          'offset': 'PT2M28.04S',
#          'channel': 0,
#          'duration': 'PT0.92S',
#          'offsetInTicks': 1480400000.0,
#          'durationInTicks': 9200000.0,
#          'recognitionStatus': 'Success',
#          'offsetMilliseconds': 148040,
#          'durationMilliseconds': 920}],
#        'durationMilliseconds': 150600,
#        'combinedRecognizedPhrases': [{'itn': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है मतलब अपा जीतने भी इंसान है क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी थोड़े फ़ोन पे मैसेज आना है सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े 24 पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम ओके सर',
#          'channel': 0,
#          'display': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर। हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके, बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में। हाँ जी, बीएन सिंह जी, ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर, पानी लागने अंदर है। दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है। मतलब अपा जीतने भी इंसान है। क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके? सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है। थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है, ठीक है ना? और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी। थोड़े फ़ोन पे मैसेज आना है। सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई। ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी, थोड़ी सी पानी भी बचत हुई। एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर। उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है, कदु करना है, है ना? इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है, मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना? जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी, ओनली जल्दी रबड़ की है ना? सर, कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े 24 पैदावार है। और भी बचूगी हाँ जी ठीक है सर हाँ जी सर, समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके, थैंक यू मैडम। ओके सर।',
#          'lexical': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है मतलब अपा जीतने भी इंसान है क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी थोड़े फ़ोन पे मैसेज आना है सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम ओके सर',
#          'maskedITN': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर। हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में। हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है। दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है। मतलब अपा जीतने भी इंसान है। क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है। थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी। थोड़े फ़ोन पे मैसेज आना है। सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई। ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई। एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर। उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े 24 पैदावार है। और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम। ओके सर।'}]}]},
#     'task_id': '1b9c73f682c540d7b58f63dd0c5972c1',
#     'provider': 'AZURE',
#     'dataset_id': '1f5f5f971e8b4a59bd7edb1069611160',
#     'output_file': 'https://karyaaisa.blob.core.windows.net/langserver/1b9c73f682c540d7b58f63dd0c5972c1.json'},
#    'created_at': '2025-07-27T13:36:00.102580',
#    'updated_at': None}]}

# %%
transcript= extract_asr_transcript(result_data)

# %%
print(transcript)
# Out:
# {'text': 'हैलो हैलो हाँ जी सस्तिकल जी कल कर रहे थे हाँ जी देव सिंह जी मैं कल्टीवेट कंपनी पटियाले तो कल कर रही है थोड़े को ना लड़का आया उन्होंने कार्बन प्रोग्राम पर हाँ जी हाँ मैं मैडम वो जी ओके ओके ओके बस तनु यही पूछना थी सर तनु सारी चीज़ क्लियर है ना कोई कॅन्फ़्यूज़न कोई ना समझ आयी हो वे तो उसी में हाँ जी बीएन सिंह जी ये पता है कि हुंडई जीने अपा खेतदेविच जदों चुना गोनिया था कई बारी आपा सताओ ऊपर सुखी देके न पर पानी लागने अंदर है दूजी का जो तो आप पानी ज्यादा देर खड़ा रख दिया है तो कुछ नोट गीता होना के बुलबुली उठ देने पानी देवी ओह मिथेन गैस फूँदी है मतलब अपा जीतने भी इंसान है क्या जानवरानु और फसल भी नुकसान पहुँचाउंगी है और ज्यादा पानी लान करके सेंसर थोड़े खेत देबीच लगेगा और देसी पाइप लग रहा है थोड़े खेत देबीच लग चुका वो और ना ना थोड़ी फसल को नुकसान होने ना उन्हें ज्यादा जगह गैर नहीं है ठीक है ना और थोड़े फ़ोन से वाला अटैच हो चुका जो थोड़े खेत में पानी भी लोड होगी थोड़े फ़ोन पे मैसेज आना है सिंह जी थोड़े खेत देवी पानी दी नमी ये नमी दी मात्रा काट गई ये कृपा मोटर चला दो ठीक है जो दो खेत देवी से नमी दी मात्रा पूरी होगी थोड़ी सी पानी भी बचत हुई एक अपने समय भी बचत हुई कई बार ही जीना दे खेत हो ना दे करा तो दूर नहीं सर उन्होंने बार बार देखने जाना भी पर गया कि ना बंदा करना है कदु करना है है ना इतना समय बच गया सर बेशक अपन पानी पे या बिजली पे सब्सिडी मिल रही है मोटर भी मेंटेनेंस पे खर्चा तो आपका ही लोन है ना जितनी ज्यादा मोटर चलोगी ओनली जल्दी खराब होगी ओनली जल्दी रबड़ की है ना सर कुल्लू बनाके जोड़ा हेगा और थोड़ा सा भी बचूगा सर बिजली भी बचूगी पानी भी बचूगा और जोड़े खेत में भी खेती भी पैदावार है यानी थोड़े चौबीस पैदावार है और भी बचूगी हाँ जी ठीक है सर हाँ जी सर समा देने में से थोड़ा बहुत बहुत धन्यवाद सर ओके थैंक यू मैडम ओके सर', 'chunks': [{'text': 'हैलो', 'timestamp': (2.32, 2.48)}, {'text': 'हैलो', 'timestamp': (2.48, 2.64)}, {'text': 'हाँ', 'timestamp': (4.84, 4.96)}, {'text': 'जी', 'timestamp': (4.96, 5.16)}, {'text': 'सस्तिकल', 'timestamp': (5.16, 5.68)}, {'text': 'जी', 'timestamp': (5.68, 5.88)}, {'text': 'कल', 'timestamp': (6.44, 6.64)}, {'text': 'कर', 'timestamp': (6.64, 6.8)}, {'text': 'रहे', 'timestamp': (6.8, 6.96)}, {'text': 'थे', 'timestamp': (6.96, 7.12)}, {'text': 'हाँ', 'timestamp': (7.96, 8.12)}, {'text': 'जी', 'timestamp': (8.12, 8.24)}, {'text': 'देव', 'timestamp': (8.92, 9.08)}, {'text': 'सिंह', 'timestamp': (9.12, 9.32)}, {'text': 'जी', 'timestamp': (9.32, 9.4)}, {'text': 'मैं', 'timestamp': (9.4, 9.56)}, {'text': 'कल्टीवेट', 'timestamp': (9.56, 10.04)}, {'text': 'कंपनी', 'timestamp': (10.04, 10.44)}, {'text': 'पटियाले', 'timestamp': (10.44, 10.88)}, {'text': 'तो', 'timestamp': (10.88, 11.0)}, {'text': 'कल', 'timestamp': (11.0, 11.2)}, {'text': 'कर', 'timestamp': (11.2, 11.36)}, {'text': 'रही', 'timestamp': (11.36, 11.64)}, {'text': 'है', 'timestamp': (11.72, 11.8)}, {'text': 'थोड़े', 'timestamp': (12.08, 12.4)}, {'text': 'को', 'timestamp': (12.4, 12.52)}, {'text': 'ना', 'timestamp': (12.56, 12.72)}, {'text': 'लड़का', 'timestamp': (13.68, 14.0)}, {'text': 'आया', 'timestamp': (14.0, 14.28)}, {'text': 'उन्होंने', 'timestamp': (14.36, 14.72)}, {'text': 'कार्बन', 'timestamp': (14.72, 15.16)}, {'text': 'प्रोग्राम', 'timestamp': (15.2, 15.6)}, {'text': 'पर', 'timestamp': (15.6, 15.92)}, {'text': 'हाँ', 'timestamp': (18.12, 18.2)}, {'text': 'जी', 'timestamp': (18.2, 18.36)}, {'text': 'हाँ', 'timestamp': (18.36, 18.6)}, {'text': 'मैं', 'timestamp': (18.6, 18.84)}, {'text': 'मैडम', 'timestamp': (19.84, 20.08)}, {'text': 'वो', 'timestamp': (20.12, 20.6)}, {'text': 'जी', 'timestamp': (20.6, 20.72)}, {'text': 'ओके', 'timestamp': (21.16, 21.84)}, {'text': 'ओके', 'timestamp': (22.08, 22.72)}, {'text': 'ओके', 'timestamp': (22.72, 22.92)}, {'text': 'बस', 'timestamp': (22.92, 23.36)}, {'text': 'तनु', 'timestamp': (23.36, 23.56)}, {'text': 'यही', 'timestamp': (23.56, 23.8)}, {'text': 'पूछना', 'timestamp': (23.8, 24.16)}, {'text': 'थी', 'timestamp': (24.16, 24.24)}, {'text': 'सर', 'timestamp': (24.24, 24.44)}, {'text': 'तनु', 'timestamp': (24.44, 24.68)}, {'text': 'सारी', 'timestamp': (24.72, 25.08)}, {'text': 'चीज़', 'timestamp': (25.08,  ...
