# %%
from packages.transcripts import transcribe_with_timestamps
from packages.PII_detection import detect_pii_entities
from packages.mapTimeStamps import map_pii_to_timestamps
from packages.saveRedactedAudio import redact_audio
from packages.getTranscript import process_asr

# %%
input_audio_path = r"inputs\in-9872019796-1001-20250530-154113-1748599873.42156.wav"

# %% [markdown]
# ### 🎙️ Step 1: Transcribe Hindi Audio with Word-Level Timestamps
#
# This function uses Azure's Speech SDK to transcribe a WAV audio file in Hindi (`hi-IN`) and extract:
#
# - Recognized speech as text.
# - Word-level timestamps including start and end time (in seconds).
#
# The results are collected and returned in a structured dictionary with `text` and `chunks`.

# %%
# transcript = transcribe_with_timestamps(input_audio_path)
transcript = process_asr(input_audio_path)
print(transcript)
# Out:
# Status code: 200
# Response JSON: {'task_id': '25fd82a77a7b44d5859457f7145af6ec', 'dataset_id': 'cd0a05e7e9ae48d0a043a1d1c511f2ef', 'status': 'PENDING', 'skipped_file': []}
# Submitted transcription task. Task ID: 25fd82a77a7b44d5859457f7145af6ec
# Polling for completion...
# Polling attempt 1, Status Code: 200
# Current status: PENDING
# Polling attempt 2, Status Code: 200
# Current status: PENDING
# Polling attempt 3, Status Code: 200
# Current status: COMPLETED
# {'text': 'हैलो हैलो हैलो हाँ जी सुस्तिका जी कुलदीप सिंह से कॉल कर रही हूँ हाँ जी हाँ जी कुलदीप जी मैं कल्टीवेट कंपनी पटियाले तो कल कर दिया नकबीर सिंह भी आए उन्होंने उन्होंने सर कार्बन क्रेडिट प्रोग्राम बारे जानकारी देती हूँ होनी सर ठीक है सर कंपनी वेलकम कॉल है तो दूसरा प्रोजेक्ट वाले कुछ भी समझ नहीं आया कुछ जानना चाह रही हो तो उसी में मैं पूछ सकती हूँ चलो समझ आया की आपका ही सेंसर या पाइप थोड़े खेतांच क्यों लोने नहीं ओके कुलदीप सिंह जी एक ये है की जिन्हें अपा कई बार ही जो में भी फसल से तो लाद नहीं है ना वो तो ठीक है पहला में तो ये सेंसर कम की कर देने ये सेंसर ना सर पांच इंचते डायमीटर दे हूँ देने खेत भी वाटते लागजम देने थोड़ी फसल में कोई नुकसान नहीं होता है एक ही के नीचे नमी की मात्रा काट दूंगी यानी पानी दी मात्रा भी लोड होगी पानी दी लोड होगी मैसेज आएगा अभी कुलदीप सिंह जी थोड़े खेत के अंदर नमीदी मात्रा काट गई है कृप्या करके मोटर चला दो ठीक है दे दो पानी की मात्रा पूरी हो चुकी तो ना फिर मैसेज आएगा अभी कुलदीप सिंह जी मोटर बंद कर दो नमीदी मात्रा पूरी होगी आप पहले ये क्यों है ना सब तो फ्री ऑफ़ कॉस्ट है तो कोई पैसा नहीं है तुझे किसे को देना दूजी काल कई बार ही की बहुत सारे फार्मर थे यानी की किसान देख ये तो दूर होते नहीं उन्होंने बार बार देखा जाना पहना है अभी मोटर दी लोड है चलाइए ना चलाइए है ना दूजा में स्टार्टिंग से ही दस्ता के पास सता सुखी देख के कई बार ही पानी लादे बट अंदर पानी हुंदा है खेत जमीन दे अंदर तो अपनी पानी भी बचत करा होगा सर पहला बिजली की सब्सिडी है बट मोटर का चल रही है ना सर सर जो तो आपका ज्यादा पानी लाने हैं ना तो फसल को उल्ले की बीमारी और वो महंगी बहुत है है ना सर तक ही कम है और क्यों अपना करना है ये दोनों जानकारी है मैं उन्हें देती हूँ और ये भी दस तक कोई भी पैसा तो नहीं देना है सर ये तो सी एडवाइजरी के मुताबिक खेत दे भी पानी लाउंगे सर ठीक है जी ठीक है सर बहुत बहुत धन्यवाद सर किसी भी तरीके से कोई और जानकारी जानना चाह रही हूँ प्रोजेक्ट में लेके तो पूछ सकती हूँ सर मेरी बात जी ओके बहुत बहुत धन्यवाद सर थोड़ा समते सर श्रीकाल जी जी', 'chunks': [{'text': 'हैलो', 'timestamp': (2.4, 2.8)}, {'text': 'हैलो', 'timestamp': (5.8, 6.32)}, {'text': 'हैलो', 'timestamp': (9.04, 9.32)}, {'text': 'हाँ', 'timestamp': (9.32, 9.48)}, {'text': 'जी', 'timestamp': (9.48, 9.6)}, {'text': 'सुस्तिका', 'timestamp': (9.6, 9.96)}, {'text': 'जी', 'timestamp': (10.0, 10.12)}, {'text': 'कुलदीप', 'timestamp': (10.12, 10.48)}, {'text': 'सिंह', 'timestamp': (10.52, 10.68)}, {'text': 'से', 'timestamp': (10.68, 10.8)}, {'text': 'कॉल', 'timestamp': (10.8, 11.0)}, {'text': 'कर', 'timestamp': (11.0, 11.12)}, {'text': 'रही', 'timestamp': (11.12, 11.36)}, {'text': 'हूँ', 'timestamp': (11.36, 11.44)}, {'text': 'हाँ', 'timestamp': (12.04, 12.16)}, {'text': 'जी', 'timestamp': (12.16, 12.24)}, {'text': 'हाँ', 'timestamp': (12.24, 12.36)}, {'text': 'जी', 'timestamp': (12.4, 12.6)}, {'text': 'कुलदीप', 'timestamp': (12.96, 13.36)}, {'text': 'जी', 'timestamp': (13.36, 13.48)}, {'text': 'मैं', 'timestamp': (13.48, 13.6)}, {'text': 'कल्टीवेट', 'timestamp': (13.6, 14.08)}, {'text': 'कंपनी', 'timestamp': (14.08, 14.48)}, {'text': 'पटियाले', 'timestamp': (14.48, 14.92)}, {'text': 'तो', 'timestamp': (14.92, 15.0)}, {'text': 'कल', 'timestamp': (15.0, 15.2)}, {'text': 'कर', 'timestamp': (15.2, 15.4)}, {'text': 'दिया', 'timestamp': (15.4, 15.84)}, {'text': 'नकबीर', 'timestamp': (17.36, 18.12)}, {'text': 'सिंह', 'timestamp': (18.2, 18.4)}, {'text': 'भी', 'timestamp': (18.44, 18.6)}, {'text': 'आए', 'timestamp': (18.6, 18.76)}, {'text': 'उन्होंने', 'timestamp': (18.76, 19.32)}, {'text': 'उन्होंने', 'timestamp': (19.36, 19.64)}, {'text': 'सर', 'timestamp': (20.28, 20.4)}, {'text': 'कार्बन', 'timestamp': (20.48, 20.96)}, {'text': 'क्रेडिट', 'timestamp': (20.96, 21.36)}, {'text': 'प्रोग्राम', 'timestamp': (21.36, 21.8)}, {'text': 'बारे', 'timestamp': (21.8, 22.04)}, {'text': 'जानकारी', 'timestamp': (22.04, 23.16)}, {'text': 'देती', 'timestamp': (23.56, 24.56)}, {'text': 'हूँ', 'timestamp': (25.28, 25.36)}, {'text': 'होनी', 'timestamp': (26.2, 26.76)}, {'text': 'सर', 'timestamp': (26.76, 27.04)}, {'text': 'ठीक', 'timestamp': (27.96, 28.16)}, {'text': 'है', 'timestamp': (29.44, 29.6)}, {'t ...

# %%
transcript['text']
# Out:
# 'हैलो हैलो हैलो हाँ जी सुस्तिका जी कुलदीप सिंह से कॉल कर रही हूँ हाँ जी हाँ जी कुलदीप जी मैं कल्टीवेट कंपनी पटियाले तो कल कर दिया नकबीर सिंह भी आए उन्होंने उन्होंने सर कार्बन क्रेडिट प्रोग्राम बारे जानकारी देती हूँ होनी सर ठीक है सर कंपनी वेलकम कॉल है तो दूसरा प्रोजेक्ट वाले कुछ भी समझ नहीं आया कुछ जानना चाह रही हो तो उसी में मैं पूछ सकती हूँ चलो समझ आया की आपका ही सेंसर या पाइप थोड़े खेतांच क्यों लोने नहीं ओके कुलदीप सिंह जी एक ये है की जिन्हें अपा कई बार ही जो में भी फसल से तो लाद नहीं है ना वो तो ठीक है पहला में तो ये सेंसर कम की कर देने ये सेंसर ना सर पांच इंचते डायमीटर दे हूँ देने खेत भी वाटते लागजम देने थोड़ी फसल में कोई नुकसान नहीं होता है एक ही के नीचे नमी की मात्रा काट दूंगी यानी पानी दी मात्रा भी लोड होगी पानी दी लोड होगी मैसेज आएगा अभी कुलदीप सिंह जी थोड़े खेत के अंदर नमीदी मात्रा काट गई है कृप्या करके मोटर चला दो ठीक है दे दो पानी की मात्रा पूरी हो चुकी तो ना फिर मैसेज आएगा अभी कुलदीप सिंह जी मोटर बंद कर दो नमीदी मात्रा पूरी होगी आप पहले ये क्यों है ना सब तो फ्री ऑफ़ कॉस्ट है तो कोई पैसा नहीं है तुझे किसे को देना दूजी काल कई बार ही की बहुत सारे फार्मर थे यानी की किसान देख ये तो दूर होते नहीं उन्होंने बार बार देखा जाना पहना है अभी मोटर दी लोड है चलाइए ना चलाइए है ना दूजा में स्टार्टिंग से ही दस्ता के पास सता सुखी देख के कई बार ही पानी लादे बट अंदर पानी हुंदा है खेत जमीन दे अंदर तो अपनी पानी भी बचत करा होगा सर पहला बिजली की सब्सिडी है बट मोटर का चल रही है ना सर सर जो तो आपका ज्यादा पानी लाने हैं ना तो फसल को उल्ले की बीमारी और वो महंगी बहुत है है ना सर तक ही कम है और क्यों अपना करना है ये दोनों जानकारी है मैं उन्हें देती हूँ और ये भी दस तक कोई भी पैसा तो नहीं देना है सर ये तो सी एडवाइजरी के मुताबिक खेत दे भी पानी लाउंगे सर ठीक है जी ठीक है सर बहुत बहुत धन्यवाद सर किसी भी तरीके से कोई और जानकारी जानना चाह रही हूँ प्रोजेक्ट में लेके तो पूछ सकती हूँ सर मेरी बात जी ओके बहुत बहुत धन्यवाद सर थोड़ा समते सर श्रीकाल जी जी'

# %% [markdown]
# ### 🕵️ Step 2: Detect PII Entities in Hindi Text
#
# This function uses the Azure client to recognize PII entities in a Hindi document. It:
#
# - Calls Azure's `recognize_pii_entities()` method with language set to `"hi"` (Hindi).
# - Prints redacted text and detailed info for each detected entity.
# - Returns a list of all PII words detected in the input.

# %%
asr_text = [transcript['text']]
pii_result = detect_pii_entities(asr_text)
pii_words = []
for doc in pii_result:
    print("Redacted Text: {}".format(doc.redacted_text))
    for entity in doc.entities:
        if entity.confidence_score > 0.7 and entity.category in  ['Person', 'Organization', 'PhoneNumber', 'Address', 'Location', 'PhoneNumber', 'BankAccountNumber']:
            print("Entity: {}".format(entity.text))
            pii_words.append(entity.text)
            print("\tCategory: {}".format(entity.category))
            print("\tConfidence Score: {}".format(entity.confidence_score))
            print("\tOffset: {}".format(entity.offset))
            print("\tLength: {}".format(entity.length))
# Out:
# Redacted Text: ਹੈਲੋ ਹਾਂਜੀ ਹਾਂਜੀ ******* ਵੀ ਕਟ ਗਏ ਸੀਗਾ। ਤੁਹਾਡੇ ਕੋਲੇ ਨਾ ********** ਦੀ ਆਏ ਸੀ। ਮੈਂ ਤੁਹਾਨੂੰ। ਕਾਰਬਨ ਕ੍ਰੇਡਿਟ ਬਾਰੇ ਜਾਣਕਾਰੀ ਦਿੱਤੀ ਸੀ। ਪਾਈਪ ਲਗਦੇ ਨੇ ਪਾਣੀ ਦਾ ਸੁਨੇਹਾ ਲਾਉਂਦੇ ਨੇ ਆਪਾਂ ਨੂੰ। ਮੈਂ ਕਦੀ ਜਿਹੜੇ ਖੇਤਾਂ ਦੇ ਵਿੱਚ ਪਾਈਪ ਲੱਗਦੀ ਆ ਨਾ ਆਪਾ ਨੂੰ ਪਾਣੀ ਦਾ ਸੁਨੇਹਾ ਲਾਉਂਦੇ ਨੇ। ਜੀ। ਉਹਦੇ ਬਾਰੇ ਤੁਹਾਨੂੰ ************* ਦੱਸਣ ਆਏ ਸੀਗੇ। ਹੈਲੋ ਕੌਣ ਬੋਲ ਰਿਹਾ ਜੀ ਸਾਰੀ ਤੁਸੀ ਟ੍ਰੈਕਟਰ ਚਲਾ ਰਹੇ ਹੋ। ਮੈਂ ਤੁਹਾਨੂੰ ਤੰਗ ਕਰ ਰਹੀ ਹਾਂ। ਤੁਹਾਡੇ ਕੋਲ ਨਾ ********** ਜੀ ਆਏ ਸੀਗੇ ਉਹਨਾਂ ਨੇ ਤੁਹਾਨੂੰ ਸੈਂਸਰ ਦੇ ਬਾਰੇ ਜਾਣਕਾਰੀ ਦਿੱਤੀ ਸੀ। ਕਾਰਬਨ ਕ੍ਰੇਡਿਟ ਪ੍ਰੋਗਰਾਮ ਬਾਰੇ ਇਹਨਾਂ ਸਿਰ ਖੇਤਾਂ ਦੇ ਵਿੱਚ ਪਾਈਪ ਲੱਗ ਜਾਂਦੇ ਨੇ ਜੋ ਤੁਹਾਡੇ ਫੋਨ ਦੇ ਨਾਲ ਅਟੈਚ ਹੋ ਜਾਂਦੇ ਨੇ। ਜਦੋਂ ਵੀ ਤੁਹਾਡੇ ਖੇਤ ਨੂੰ ਪਾਣੀ ਦੀ ਲੋੜ ਹੁੰਦੀ ਹੈ ਨਾ ਤੁਹਾਡੇ ਫੋਨ ਤੇ ਮੈਸੇਜ ਆਉਂਦਾ ਵੀ ************ ਜੀ ਆਪਣੇ ਖੇਤ ਚੋਂ ਮੋਟਰ ਲਾਦੋ ਨਵੀਂ ਦੀ ਮਾਤਰਾ ਘੱਟ ਗਈ। ਐ ਹਾਂ, ਜੀ ਕੇ ਥੋਡੇ ਕੋਲ ***** ਹਾਂ ਜੀ ਹਾਂ ਜੀ ਹਾਂ ਜੀ ਬੈਠੇ ਰਹੇ ਤੋਂ। ਤੇ ਥੋਨੂੰ ਪੂਰੀ ਜਾਣਕਾਰੀ ਸਮਝ ਆ ਗਈ ਤੇ ਤੁਸੀਂ ਕੁੱਝ ਹੋਰ ਪੁੱਛਣਾ ਚਾਹੁੰਨੇ ਓਂ। ਖਰਚਾ ਖੁਰਚਾ ਕੀ ਹੁੰਦਾ ਕੋਈ ਖਰਚਾ ਨਹੀਂ ਜੀ ਤੁਸੀਂ ਇੱਕ ਸਿੰਗਲ ਰਪਇਆਂ ਨਹੀਂ ਦੇਣਾ। ਸਾਨੂੰ ਨਾ ਪਾਈਪ ਚਲਾਏਗਾ ਨਾ ਪਾਈਪ ਕੱਢੇ ਦਾ ਨਾ ਮੈਸੇਜ ਆਏਗਾ ਇਸ ਪ੍ਰੀ ਸਰਵਿਸ ਹੈ। ਠੀਕ ਹੈ ਤੇ ਕਦੋਂ ਲਾਰੇ? ਤੁਹਾਡਾ ਇਹ ਇਹ ਸਿਰ ਬੜੀ ਜ਼ਲਦੀ ਮਤਲਬ ਜੂਨ 00 ਮੱਡ ਜਿਹਦੇ ਵਿੱਚ ਲੱਗਣੇ ਸ਼ੁਰੂ ਹੋ ਜਾਣਗੇ ਇਹ ਕਨਫਰਮੇਸ਼ਨ ਕਾਲ ਜਾਰੀ ਹੈ। ਜਿੰਨੇ ਵੀ ਫ਼ਾਰਮ ਅਸੀਂ ਆਨ ਬੋਰਡ ਕੀਤੇ ਨੇ। ਅਸੀਂ ਆਨ ਬੋਰਡ ਕਰਨਾ ਕਹਿ ਦਿੰਦੇ ਹਾਂ। ਅਸੀਂ ਜਿਹਨਾਂ ਤੋਂ ਅਸੀਂ ਪਰਮਿਸ਼ਨ ਲੈ ਕੇ ਆਏ ਹਾਂ ਵੀ ਤੁਸੀਂ ਪਾਈਪ ਲੈਣਾ ਚਾਹੁੰਦੇ ਹੋ ਤਾਂ ਉਹਦੇ ਚ ਨਾ ਸਾਰੇ ਫ਼ਾਰਮਰੀਆਂ ਦੇ ਨਹੀਂ ਲਗਦੇ ਹੈਗੇ ******* ਜੀ ਸਲੈਕਟ ਕੀਤੇ ਜਾਂਦੇ ਨੇ ਬੰਦੇ। ਠੀਕ ਆ ਜੀ ਇੱਕ ਕਿਹੜੇ ਚੰਦ ******* ਨੂੰ ਜੀ ਲਗਾਉਣੇ। ਠੀਕ ਹੈ ਜੀ ਮੈ ਮ ਤਾਂ ਕੋਸ਼ਿਸ਼ ਕਰਾਂਗੇ ਕਿ ਹਰ ਫ਼ਾਰਮਤ ਆ ਜਾਵੇ। ਉਹਦੇ ਚ ਨੰਬਰ ਕਿਉਂਕਿ ਫ਼੍ਰੀ ਆਫ਼ ਕੋਸਟ ਹੈ ਨਾ ਸਿਰ ਸਰਵਿਸ ਤਾਂ ਹਰ ਕਿਸੇ ਨੂੰ ਨਹੀਂ ਦੇ ਪਾਂਦੇ ਹਾਂ ਕਿ ਆਪਾਂ ਸਲੈਕਟ ਕਰਦੇ ਹਾਂ ਜਿਹੜੀਆ ਫ਼ਾਰਮ ਤੇ ਤੁਸੀਂ ਕਿੰਨੇ ਕਿੱਲਿਆਂ ਦੀ ਵਾਹੀ ਕਰਦੇ ਓਂ? ***************। ਓਹਦੀ ਦੱਸ ** ਕਿੰਨਾ ਦੀ ਕਰਦੇ ਜੀ ***। ਥੋਡੀ ਫ਼ੈ**** ਦਾ ਇਕੱਠਾ ਜਾਰੀ ਕਿੱਲੇ ਹੈ। ***** ਇਸ ਫ਼ੈਮਿਲੀ ਚਾਚੀ ਕੇ ਵਿੱਚੇ ਸਾਰਾ ਕੁਛ ਆ ਜਾਂਦਾ। ਠੀਕ ਹੈ ਜਦੋਂ ਕੋਈ ਨਹੀਂ। ₹0.00 ਬਿਜਲੀ ਚੋਂ ਨਾ ਫਿਰ ਕਰਿਜੀ ਗੱਲ ਹੈ। ਹਾਂ ਜੀ ਹਾਂ ਜੀ ਕਰੋ ਸਿਰ ਕਰੋ ਕਰੋ।
# Entity: ਬਲਵਿੰਦਰ
# 	Category: Person
# 	Confidence Score: 0.96
# 	Offset: 17
# 	Length: 7
# Entity: ਜਸਵੰਤ ਸਿੰਘ
# 	Category: Person
# 	Confidence Score: 0.96
# 	Offset: 55
# 	Length: 10
# Entity: ਜਸਵੰਤ ਸਿੰਘ ਜੀ
# 	Category: Person
# 	Confidence Score: 0.9
# 	Offset: 274
# 	Length: 13
# Entity: ਜਸਵੰਤ ਸਿੰਘ
# 	Category: Person
# 	Confidence Score: 0.94
# 	Offset: 395
# 	Length: 10
# Entity: ਬਲਵਿੰਦਰ ਸਿੰਘ
# 	Category: Person
# 	Confidence Score: 0.92
# 	Offset: 651
# 	Length: 12
# Entity: ਜਸਵੰਤ
# 	Category: Person
# 	Confidence Score: 0.86
# 	Offset: 734
# 	Length: 5
# Entity: ਬਲਵਿੰਦਰ
# 	Category: Person
# 	Confidence Score: 0.8
# 	Offset: 1293
# 	Length: 7
# Entity: ਬਲਵਿੰਦਰ ਸਿੰਘ ਜੀ
# 	Category: Person
# 	Confidence Score: 0.91
# 	Offset: 1591
# 	Length: 15
# Entity: ਹਾਂਜੀ
# 	Category: Person
# 	Confidence Score: 0.87
# 	Offset: 1679
# 	Length: 5

# %% [markdown]
# ### 🧠 Step 3: Map PII Words to Audio Word Timestamps
#
# This function attempts to align each detected PII word to a timestamped word chunk in the ASR output using:
#
# - Fuzzy string matching (`SequenceMatcher`) to allow for slight mismatches.
# - Returns a list of timestamps corresponding to each PII word.
#
# This is crucial for knowing **where** in the audio to apply redaction.

# %%
print(pii_words)

# %%
pii_segments = map_pii_to_timestamps(pii_words, transcript['chunks'], threshold=0.5)
print(pii_segments)
# Out:
# [(10.92, 11.16), (13.03, 13.55), (13.75, 14.15), (14.51, 14.95), (45.87, 46.83), (74.63, 75.03)]

# %%
len(pii_segments)
# Out:
# 6

# %% [markdown]
# ### 🔇 Step 4: Mute Audio Segments Containing PII
#
# This function takes the original audio file and the timestamps of detected PII, and:
#
# - Loads the audio using `torchaudio`.
# - Silences the waveform between each PII segment (sets amplitude to zero).
# - Saves the redacted audio file to `output_audio/` directory, replacing `"in-"` with `"out-"` in the filename.

# %%
redact_audio(input_audio_path,pii_segments, output_path="outputs")
# Out:
# ✅ Redacted audio saved at: output_audio\out-8968336334-1001-20250530-150555-1748597755.42124.wav
